# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import lightgbm as lgb
import catboost as cb
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
import warnings
import gc

warnings.filterwarnings('ignore')

# --- 1. Load Data ---
# Updated file paths based on your new code structure.
try:
    df_train = pd.read_csv('training_data/train/train.csv')
    df_transactions = pd.read_csv('training_data/train/transactions.csv')
    df_test = pd.read_csv('testing data/test_8gqdJqH.csv')
    print("All data files loaded successfully.")
except FileNotFoundError as e:
    print(f"Error loading data files: {e}")
    print("Please ensure your folder structure and file names are correct.")
    exit()

# --- 2. Initial Data Cleaning & Type Conversion ---
print("\n--- Starting Data Cleaning and Preprocessing ---")

# Convert date columns to datetime objects
for df in [df_train, df_transactions, df_test]:
    df['doj'] = pd.to_datetime(df['doj'])
if 'doi' in df_transactions.columns:
    # Corrected line: apply to_datetime directly to df_transactions['doi']
    df_transactions['doi'] = pd.to_datetime(df_transactions['doi']) 

print("Date columns converted to datetime objects.")

# --- 3. Feature Engineering Function ---
def create_common_features(df):
    """
    Creates common time-series features from the dataframe's 'doj' column.
    """
    df['month'] = df['doj'].dt.month
    df['year'] = df['doj'].dt.year
    df['day_of_week'] = df['doj'].dt.dayofweek  # Monday=0, Sunday=6
    df['day_of_year'] = df['doj'].dt.dayofyear
    df['week_of_year'] = df['doj'].dt.isocalendar().week.astype(int)
    df['is_weekend'] = (df['doj'].dt.dayofweek >= 5).astype(int) # Saturday or Sunday
    df['day_of_month'] = df['doj'].dt.day
    df['is_month_start'] = df['doj'].dt.is_month_start.astype(int)
    df['is_month_end'] = df['doj'].dt.is_month_end.astype(int)
    
    # Create a unique route identifier
    df['route'] = df['srcid'].astype(str) + '_' + df['destid'].astype(str)
    
    return df

def prepare_transaction_features(df_transactions_raw):
    """
    Prepares features from transactions data, including features from various dbd values.
    """
    print("Preparing transaction-based features (dbd values).")
    
    # Define a set of dbd values to extract features from
    dbd_values_to_include = [5, 10, 15, 20, 25] # Including 15 as per original logic, and surrounding values
    
    # Initialize a list to hold processed transaction segments
    transaction_features_list = []

    # Ensure transaction data is sorted for consistent pivoting/merging later
    df_transactions_raw = df_transactions_raw.sort_values(by=['doj', 'srcid', 'destid', 'dbd']).copy()

    for dbd_val in dbd_values_to_include:
        df_temp = df_transactions_raw[df_transactions_raw['dbd'] == dbd_val].copy()
        
        # Select relevant columns and rename them to include dbd_val suffix
        df_temp = df_temp[['doj', 'srcid', 'destid', 'cumsum_seatcount', 'cumsum_searchcount', 
                           'srcid_region', 'destid_region', 'srcid_tier', 'destid_tier']]
        
        df_temp.rename(columns={
            'cumsum_seatcount': f'cumsum_seatcount_dbd_{dbd_val}',
            'cumsum_searchcount': f'cumsum_searchcount_dbd_{dbd_val}',
            'srcid_region': f'srcid_region_dbd_{dbd_val}', # These will be largely redundant, but for safety
            'destid_region': f'destid_region_dbd_{dbd_val}',
            'srcid_tier': f'srcid_tier_dbd_{dbd_val}',
            'destid_tier': f'destid_tier_dbd_{dbd_val}'
        }, inplace=True)
        transaction_features_list.append(df_temp)

    # Merge all dbd-specific features into a single DataFrame
    # Start with the first dbd value, then iteratively merge others
    if not transaction_features_list:
        return pd.DataFrame(columns=['doj', 'srcid', 'destid']) # Return empty if no dbd values
        
    df_transaction_features = transaction_features_list[0]
    for i in range(1, len(transaction_features_list)):
        df_transaction_features = pd.merge(
            df_transaction_features,
            transaction_features_list[i],
            on=['doj', 'srcid', 'destid'],
            how='outer' # Use outer to keep all unique combinations, then fillna later
        )
    
    # Drop duplicate categorical columns (they should be identical across dbd values if present)
    # Keeping only one set for region/tier features, preferably from dbd=15
    for col in ['srcid_region', 'destid_region', 'srcid_tier', 'destid_tier']:
        if f'{col}_dbd_15' in df_transaction_features.columns:
            df_transaction_features[col] = df_transaction_features[f'{col}_dbd_15']
            for dbd_val in dbd_values_to_include:
                if f'{col}_dbd_{dbd_val}' in df_transaction_features.columns and dbd_val != 15:
                    df_transaction_features.drop(columns=f'{col}_dbd_{dbd_val}', inplace=True)
        else: # If dbd=15 is not present for some reason, pick the first available
             for dbd_val in dbd_values_to_include:
                if f'{col}_dbd_{dbd_val}' in df_transaction_features.columns:
                    df_transaction_features[col] = df_transaction_features[f'{col}_dbd_{dbd_val}']
                    for dv in dbd_values_to_include:
                        if f'{col}_dbd_{dv}' in df_transaction_features.columns and dv != dbd_val:
                            df_transaction_features.drop(columns=f'{col}_dbd_{dv}', inplace=True)
                    break # Break after finding and setting one
    
    return df_transaction_features


print("\n--- Engineering Common and Transaction Features ---")
# Apply common feature engineering to train and test sets
df_train = create_common_features(df_train)
df_test = create_common_features(df_test)

# Prepare transaction features separately
df_transaction_features = prepare_transaction_features(df_transactions)

print("Feature engineering complete.")

# --- 4. Prepare Training and Test Data ---
print("\n--- Preparing Model Training and Test Sets ---")

# Merge transaction features with train and test labels
df_model_train = pd.merge(
    df_train,
    df_transaction_features,
    on=['doj', 'srcid', 'destid'],
    how='inner' # Keep only records present in both
)

print(f"Final training data shape after merge: {df_model_train.shape}")
if df_model_train.shape[0] != df_train.shape[0]:
    print(f"Warning: {df_train.shape[0] - df_model_train.shape[0]} records in train.csv did not have corresponding transaction data for any dbd value. These rows are dropped.")

df_model_test = pd.merge(
    df_test,
    df_transaction_features,
    on=['doj', 'srcid', 'destid'],
    how='left' # Keep all test records, fill missing transaction features with 0
)

print(f"Final test data shape after merge: {df_model_test.shape}")

# Identify columns that are not 'doj', 'srcid', 'destid', or the target
numerical_cols = [col for col in df_model_train.columns if 'cumsum' in col or 'count' in col or col in ['month', 'year', 'day_of_week', 'day_of_year', 'week_of_year', 'is_weekend', 'day_of_month', 'is_month_start', 'is_month_end']]

# Fill missing numerical features (especially in test set after left merge)
# It's crucial to fill missing dbd features after the merge.
for col in numerical_cols:
    if col in df_model_train.columns:
        df_model_train[col].fillna(0, inplace=True) # Fill with 0 for cumulative counts if not present
    if col in df_model_test.columns:
        df_model_test[col].fillna(0, inplace=True)

# Fill missing categorical features (e.g., if a region/tier was missing for a dbd value)
categorical_cols = ['srcid_region', 'destid_region', 'srcid_tier', 'destid_tier']
for col in categorical_cols:
    if col in df_model_train.columns:
        df_model_train[col].fillna('unknown', inplace=True)
    if col in df_model_test.columns:
        df_model_test[col].fillna('unknown', inplace=True)


# --- 5. Model Training and Evaluation ---
print("\n--- Training and Evaluating Multiple ML Models ---")

# Define features (X) and target (y)
# Exclude 'doj' and 'route_key' from features. 'route' is handled by encoding.
excluded_cols = ['doj', 'route_key', 'final_seatcount']
features = [col for col in df_model_train.columns if col not in excluded_cols]

X = df_model_train[features]
y_train = df_model_train['final_seatcount']
X_test_prep = df_model_test[features]

# Identify categorical features for encoding
categorical_features = [col for col in features if X[col].dtype == 'object' or X[col].nunique() < 50] # Heuristic for categorical


# One-Hot Encode categorical features for tree-based models (XGBoost, LightGBM, Random Forest, Gradient Boosting)
# CatBoost handles categoricals internally
X_train_encoded = pd.get_dummies(X, columns=categorical_features, dummy_na=False)
X_test_encoded = pd.get_dummies(X_test_prep, columns=categorical_features, dummy_na=False)

# Align columns - crucial for ensuring test set has same features as train set
X_train_encoded, X_test_encoded = X_train_encoded.align(X_test_encoded, join='left', axis=1, fill_value=0)

# Clean column names for LightGBM/XGBoost compatibility (avoiding problematic characters)
X_train_encoded.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in X_train_encoded.columns]
X_test_encoded.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in X_test_encoded.columns]


# Label encode categorical features for CatBoost (it needs integers)
# Apply Label Encoding to the original categorical features for CatBoost
cat_features_for_catboost = [col for col in categorical_features if col in X.columns] # Ensure they exist in X
for col in cat_features_for_catboost:
    le = LabelEncoder()
    # Fit on combined train and test categories to handle unseen categories in test
    combined_categories = pd.concat([X[col], X_test_prep[col]], axis=0).astype(str).unique()
    le.fit(combined_categories)
    X[col] = le.transform(X[col].astype(str))
    X_test_prep[col] = le.transform(X_test_prep[col].astype(str))

# Define models to evaluate
models = {
    'XGBoost': xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse', n_estimators=1000, 
                                learning_rate=0.05, max_depth=7, subsample=0.7, colsample_bytree=0.7, 
                                random_state=42, n_jobs=-1, tree_method='hist', # Added more estimators
                                early_stopping_rounds=50),
    'LightGBM': lgb.LGBMRegressor(objective='regression', metric='rmse', n_estimators=1000, 
                                  learning_rate=0.05, num_leaves=31, max_depth=-1, 
                                  subsample=0.7, colsample_bytree=0.7, random_state=42, n_jobs=-1,
                                  callbacks=[lgb.early_stopping(50, verbose=False)]),
    'CatBoost': cb.CatBoostRegressor(objective='RMSE', iterations=1000, learning_rate=0.05, 
                                    depth=7, l2_leaf_reg=3, random_seed=42, verbose=0,
                                    early_stopping_rounds=50,
                                    cat_features=cat_features_for_catboost),
    'GradientBoosting': GradientBoostingRegressor(n_estimators=500, learning_rate=0.05, 
                                                max_depth=5, subsample=0.7, random_state=42),
    'RandomForest': RandomForestRegressor(n_estimators=300, max_depth=10, 
                                          min_samples_leaf=5, random_state=42, n_jobs=-1)
}

# TimeSeriesSplit for cross-validation
# Ensure splits are large enough, adjusting for data size
tscv = TimeSeriesSplit(n_splits=5) 

# Store RMSE results for each model
model_rmse_scores = {}

# Iterate through models and perform cross-validation
for model_name, model in models.items():
    print(f"\n--- Evaluating {model_name} ---")
    fold_rmses = []

    # Use appropriate X_train and X_test for each model type
    current_X_train = X_train_encoded if model_name not in ['CatBoost'] else X
    current_X_test = X_test_encoded if model_name not in ['CatBoost'] else X_test_prep

    # Prepare data for CatBoost if it's the current model
    if model_name == 'CatBoost':
        # Need to re-create X and X_test_prep with label encoded categoricals each time
        # for CatBoost specifically, as other models use one-hot encoded.
        # This is handled by passing X and X_test_prep (which have been label encoded earlier)
        # and letting CatBoost's `cat_features` parameter do the rest.
        pass # X and X_test_prep already have label encoded categoricals from earlier

    # For models with early stopping, eval_set is used. For others, fit directly.
    requires_eval_set = model_name in ['XGBoost', 'LightGBM', 'CatBoost']

    for fold, (train_index, val_index) in enumerate(tscv.split(current_X_train)):
        X_train_fold, X_val_fold = current_X_train.iloc[train_index], current_X_train.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]

        if requires_eval_set:
            if model_name == 'CatBoost':
                model.fit(X_train_fold, y_train_fold, 
                          eval_set=(X_val_fold, y_val_fold),
                          verbose=False) # Keep verbose for CatBoost as it's directly supported
            else: # XGBoost, LightGBM
                # Removed verbose=False from here to avoid the TypeError
                model.fit(X_train_fold, y_train_fold,
                          eval_set=[(X_val_fold, y_val_fold)]) 
        else: # GradientBoosting, RandomForest
            model.fit(X_train_fold, y_train_fold)

        val_predictions = model.predict(X_val_fold)
        val_rmse = np.sqrt(mean_squared_error(y_val_fold, val_predictions))
        fold_rmses.append(val_rmse)
        print(f"  Fold {fold+1} RMSE: {val_rmse:.4f}")
    
    avg_rmse = np.mean(fold_rmses)
    model_rmse_scores[model_name] = avg_rmse
    print(f"Average {model_name} RMSE: {avg_rmse:.4f}\n")

    # Clear memory for the current model if possible
    del model
    gc.collect() # Garbage collection

# --- 6. Select Best Model and Retrain ---
best_model_name = min(model_rmse_scores, key=model_rmse_scores.get)
print(f"\n--- Best Model Selected: {best_model_name} with average RMSE: {model_rmse_scores[best_model_name]:.4f} ---")

best_model = models[best_model_name] # Retrieve the original model instance

# Retrain the best model on the entire training dataset
print(f"Retraining {best_model_name} on the full training data...")

# Use appropriate X_train for the best model
if best_model_name in ['CatBoost']:
    final_X_train = X
    final_X_test = X_test_prep
    # For CatBoost, the cat_features need to be specified during fit if not in constructor
    # Re-instantiate CatBoost to ensure it uses the full dataset properly
    best_model = cb.CatBoostRegressor(objective='RMSE', iterations=1000, learning_rate=0.05, 
                                    depth=7, l2_leaf_reg=3, random_seed=42, verbose=0,
                                    cat_features=cat_features_for_catboost) # No early stopping on full data
else:
    final_X_train = X_train_encoded
    final_X_test = X_test_encoded
    # For XGBoost/LightGBM, remove early_stopping_rounds for final fit on full data
    if best_model_name == 'XGBoost':
        # Removed early_stopping_rounds for final fit on full data, and verbose=False
        best_model = xgb.XGBRegressor(objective='reg:squareerrot', n_estimators=1000, 
                                    learning_rate=0.05, max_depth=7, subsample=0.7, colsample_bytree=0.7, 
                                    random_state=42, n_jobs=-1, tree_method='hist')
    elif best_model_name == 'LightGBM':
        # Removed callbacks for final fit on full data, and verbose=False
        best_model = lgb.LGBMRegressor(objective='regression', n_estimators=1000, 
                                    learning_rate=0.05, num_leaves=31, max_depth=-1, 
                                    subsample=0.7, colsample_bytree=0.7, random_state=42, n_jobs=-1)
    # For other models, no change needed

best_model.fit(final_X_train, y_train)

train_predictions = best_model.predict(final_X_train)
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
print(f"Final Training RMSE with best model ({best_model_name}): {train_rmse:.4f}")

# --- 7. Prediction and Submission File Creation ---
print("\n--- Generating Predictions and Submission File ---")

predictions = best_model.predict(final_X_test)

# Post-processing: Ensure predictions are non-negative integers
predictions[predictions < 0] = 0
predictions = np.round(predictions).astype(int)

# Create the submission file
submission_df = pd.DataFrame({'route_key': df_model_test['route_key'], 'final_seatcount': predictions})

# Save the submission file
submission_df.to_csv('submission_file.csv', index=False)

print("Submission file 'submission_file.csv' created successfully.")
print("\nTop 5 rows of the submission file:")
print(submission_df.head())

# --- 8. (Optional) Feature Importance for the Best Model ---
print(f"\n--- Top 15 Feature Importances for {best_model_name} ---")
# Feature importance might not be available or directly interpretable for all models
try:
    if hasattr(best_model, 'feature_importances_'):
        feature_imp = pd.DataFrame({'Value': best_model.feature_importances_, 'Feature': final_X_train.columns})
        print(feature_imp.sort_values(by="Value", ascending=False).head(15))
    elif hasattr(best_model, 'coef_'): # For linear models, though not used here
        print("Coefficients are not suitable for feature importance for this model type.")
    else:
        print("Feature importances not directly available for this model type.")
except Exception as e:
    print(f"Could not retrieve feature importances: {e}")
# Out:
# All data files loaded successfully.
#
# --- Starting Data Cleaning and Preprocessing ---
# Date columns converted to datetime objects.
#
# --- Engineering Common and Transaction Features ---
# Preparing transaction-based features (dbd values).
# Feature engineering complete.
#
# --- Preparing Model Training and Test Sets ---
# Final training data shape after merge: (67200, 32)
# Final test data shape after merge: (5900, 32)
#
# --- Training and Evaluating Multiple ML Models ---
#
# --- Evaluating XGBoost ---
# [0]	validation_0-rmse:1055.16459
# [1]	validation_0-rmse:1020.90100
# [2]	validation_0-rmse:990.24773
# [3]	validation_0-rmse:959.76933
# [4]	validation_0-rmse:928.58210
# [5]	validation_0-rmse:903.98006
# [6]	validation_0-rmse:881.36910
# [7]	validation_0-rmse:859.92458
# [8]	validation_0-rmse:836.69565
# [9]	validation_0-rmse:816.47558
# [10]	validation_0-rmse:798.26299
# [11]	validation_0-rmse:781.77929
# [12]	validation_0-rmse:766.08795
# [13]	validation_0-rmse:751.23733
# [14]	validation_0-rmse:738.34749
# [15]	validation_0-rmse:725.50055
# [16]	validation_0-rmse:713.56482
# [17]	validation_0-rmse:702.04612
# [18]	validation_0-rmse:691.72828
# [19]	validation_0-rmse:681.33713
# [20]	validation_0-rmse:672.03648
# [21]	validation_0-rmse:664.20632
# [22]	validation_0-rmse:655.96365
# [23]	validation_0-rmse:648.42765
# [24]	validation_0-rmse:640.64991
# [25]	validation_0-rmse:633.58489
# [26]	validation_0-rmse:628.10997
# [27]	validation_0-rmse:623.43050
# [28]	validation_0-rmse:618.58038
# [29]	validation_0-rmse:613.19461
# [30]	validation_0-rmse:608.86949
# [31]	validation_0-rmse:604.78049
# [32]	validation_0-rmse:600.27389
# [33]	validation_0-rmse:596.44229
# [34]	validation_0-rmse:592.93170
# [35]	validation_0-rmse:589.34972
# [36]	validation_0-rmse:587.32930
# [37]	validation_0-rmse:584.45711
# [38]	validation_0-rmse:581.78130
# [39]	validation_0-rmse:579.87572
# [40]	validation_0-rmse:577.03484
# [41]	validation_0-rmse:576.10278
# [42]	validation_0-rmse:573.93155
# [43]	validation_0-rmse:572.80594
# [44]	validation_0-rmse:573.05105
# [45]	validation_0-rmse:571.07594
# [46]	validation_0-rmse:571.13120
# [47]	validation_0-rmse:569.44049
# [48]	validation_0-rmse:568.94473
# [49]	validation_0-rmse:568.83473
# [50]	validation_0-rmse:569.03166
# [51]	validation_0-rmse:567.89604
# [52]	validation_0-rmse:567.17792
# [53]	validation_0-rmse:565.73144
# [54]	validation_0-rmse:565.73620
# [55]	validation_0-rmse:565.05674
# [56]	validation_0-rmse:565.38222
# [57]	validation_0-rmse:564.07767
# [58]	validation_0-rmse:562.95280
# [59]	validation_0-rmse:562.16210
# [60]	validation_0-rmse:561.31872
# [61]	validation_0-rmse:560.51057
# [62]	validation_0-rmse:559.51852
# [63]	validation_0-rmse:558.76185
# [64]	validation_0-rmse:558.97484
# [65]	validation_0-rmse:559.75635
# [66]	validation_0-rmse:558.71925
# [67]	validation_0-rmse:558.79813
# [68]	validation_0-rmse:558.04622
# [69]	validation_0-rmse:557.66983
# [70]	validation_0-rmse:557.44996
# [71]	validation_0-rmse:556.77992
# [72]	validation_0-rmse:556.61134
# [73]	validation_0-rmse:556.44190
# [74]	validation_0-rmse:556.54350
# [75]	validation_0-rmse:555.79115
# [76]	validation_0-rmse:555.58606
# [77]	validation_0-rmse:555.22087
# [78]	validation_0-rmse:555.55180
# [79]	validation_0-rmse:554.57470
# [80]	validation_0-rmse:554.13798
# [81]	validation_0-rmse:554.46569
# [82]	validation_0-rmse:553.99627
# [83]	validation_0-rmse:553.87787
# [84]	validation_0-rmse:553.27392
# [85]	validation_0-rmse:552.77831
# [86]	validation_0-rmse:552.62683
# [87]	validation_0-rmse:552.06866
# [88]	validation_0-rmse:551.63193
# [89]	validation_0-rmse:551.18235
# [90]	validation_0-rmse:550.77815
# [91]	validation_0-rmse:550.34222
# [92]	validation_0-rmse:549.71527
# [93]	validation_0-rmse:550.44374
# [94]	validation_0-rmse:550.53291
# [95]	validation_0-rmse:550.30409
# [96]	validation_0-rmse:549.95550
# [97]	validation_0-rmse:549.48391
# [98]	validation_0-rmse:549.31910
# [99]	validation_0-rmse:549.37598
# [100]	validation_0-rmse:548.82749
# [101]	validation_0-rmse:548.34733
# [102]	validation_0-rmse:547.93626
# [103]	validation_0-rmse:547.80691
# [104]	validation_0-rmse:547.24780
# [105]	validation_0-rmse:547.10176
# [106]	validation_0-rmse:546.75421
# [107]	validation_0-rmse:546.81211
# [108]	validation_0-rmse:546.85055
# [109]	validation_0-rmse:547.02985
# [110]	validation_0-rmse:544.96952
# [111]	validation_0-rmse:544.38474
# [112]	validation_0-rmse:544.14222
# [113]	validation_0-rmse:543.74633
# [114]	validation_0-rmse:543.31438
# [115]	validation_0-rmse:542.19819
# [116]	validation_0-rmse:542.98403
# [117]	validation_0-rmse:542.81624
# [118]	validation_0-rmse:542.39160
# [119]	validation_0-rmse:541.19087
# [120]	validation_0-rmse:540.88429
# [121]	validation_0-rmse:540.63843
# [122]	validation_0-rmse:540.52160
# [123]	validation_0-rmse:540.47790
# [124]	validation_0-rmse:539.87654
# [125]	validation_0-rmse:539.73193
# [126]	validation_0-rmse:539.53754
# [127]	validation_0-rmse:539.33805
# [128]	validation_0-rmse:539.15482
# [129]	validation_0-rmse:538.99428
# [130]	validation_0-rmse:538.99192
# [131]	validation_0-rmse:538.79728
# [132]	validation_0-rmse:538.70020
# [133]	validation_0-rmse:538.22048
# [134]	validation_0-rmse:537.88361
# [135]	validation_0-rmse:536.74851
# [136]	validation_0-rmse:536.51998
# [137]	validation_0-rmse:536.17425
# [138]	validation_0-rmse:536.07529
# [139]	validation_0-rmse:535.59189
# [140]	validation_0-rmse:535.53847
# [141]	validation_0-rmse:535.43632
# [142]	validation_0-rmse:535.34642
# [143]	validation_0-rmse:535.21531
# [144]	validation_0-rmse:534.79518
# [145]	validation_0-rmse:534.70868
# [146]	validation_0-rmse:534.72535
# [147]	validation_0-rmse:533.90195
# [148]	validation_0-rmse:533.71968
# [149]	validation_0-rmse:533.57520
# [150]	validation_0-rmse:533.17202
# [151]	validation_0-rmse:532.98209
# [152]	validation_0-rmse:532.63985
# [153]	validation_0-rmse:532.32219
# [154]	validation_0-rmse:532.40483
# [155]	validation_0-rmse:532.23652
# [156]	validation_0-rmse:532.32549
# [157]	validation_0-rmse:532.30431
# [158]	validation_0-rmse:532.55352
# [159]	validation_0-rmse:532.36368
# [160]	validation_0-rmse:532.27806
# [161]	validation_0-rmse:531.30723
# [162]	validation_0-rmse:530.80351
# [163]	validation_0-rmse:530.42926
# [164]	validation_0-rmse:530.34868
# [165]	validation_0-rmse:530.46556
# [166]	validation_0-rmse:530.40418
# [167]	validation_0-rmse:530.40844
# [168]	validation_0-rmse:530.32015
# [169]	validation_0-rmse:530.05162
# [170]	validation_0-rmse:528.35836
# [171]	validation_0-rmse:528.08177
# [172]	validation_0-rmse:528.25233
# [173]	validation_0-rmse:528.33277
# [174]	validation_0-rmse:528.14521
# [175]	validation_0-rmse:525.75859
# [176]	validation_0-rmse:525.48698
# [177]	validation_0-rmse:525.32347
# [178]	validation_0-rmse:524.27318
# [179]	validation_0-rmse:524.22952
# [180]	validation_0-rmse:524.23863
# [181]	validation_0-rmse:524.08791
# [182]	validation_0-rmse:523.98444
# [183]	validation_0-rmse:523.77024
# [184]	validation_0-rmse:523.67009
# [185]	validation_0-rmse:523.67627
# [186]	validation_0-rmse:523.45225
# [187]	validation_0-rmse:523.19893
# [188]	validation_0-rmse:522.97547
# [189]	validation_0-rmse:522.71882
# [190]	validation_0-rmse:522.58549
# [191]	validation_0-rmse:522.71692
# [192]	validation_0-rmse:521.91432
# [193]	validation_0-rmse:521.60354
# [194]	validation_0-rmse:521.61334
# [195]	validation_0-rmse:520.17376
# [196]	validation_0-rmse:519.95378
# [197]	validation_0-rmse:520.05412
# [198]	validation_0-rmse:519.97913
# [199]	validation_0-rmse:520.07939
# [200]	validation_0-rmse:520.02271
# [201]	validation_0-rmse:519.60979
# [202]	validation_0-rmse:519.59822
# [203]	validation_0-rmse:519.50159
# [204]	validation_0-rmse:519.35075
# [205]	validation_0-rmse:519.29616
# [206]	validation_0-rmse:519.28112
# [207]	validation_0-rmse:519.24338
# [208]	validation_0-rmse:519.30058
# [209]	validation_0-rmse:517.95626
# [210]	validation_0-rmse:517.09776
# [211]	validation_0-rmse:516.99018
# [212]	validation_0-rmse:516.85663
# [213]	validation_0-rmse:516.79028
# [214]	validation_0-rmse:516.67406
# [215]	validation_0-rmse:516.50577
# [216]	validation_0-rmse:516.30043
# [217]	validation_0-rmse:516.29575
# [218]	validation_0-rmse:515.35119
# [219]	validation_0-rmse:515.38031
# [220]	validation_0-rmse:515.35462
# [221]	validation_0-rmse:515.15753
# [222]	validation_0-rmse:515.22377
# [223]	validation_0-rmse:515.25072
# [224]	validation_0-rmse:515.29760
# [225]	validation_0-rmse:515.41629
# [226]	validation_0-rmse:515.30654
# [227]	validation_0-rmse:515.40760
# [228]	validation_0-rmse:515.32113
# [229]	validation_0-rmse:515.39230
# [230]	validation_0-rmse:515.49357
# [231]	validation_0-rmse:514.30901
# [232]	validation_0-rmse:514.40468
# [233]	validation_0-rmse:514.49347
# [234]	validation_0-rmse:514.22541
# [235]	validation_0-rmse:514.04114
# [236]	validation_0-rmse:514.01467
# [237]	validation_0-rmse:513.73472
# [238]	validation_0-rmse:513.55850
# [239]	validation_0-rmse:513.54789
# [240]	validation_0-rmse:513.53459
# [241]	validation_0-rmse:513.41785
# [242]	validation_0-rmse:513.33549
# [243]	validation_0-rmse:512.44933
# [244]	validation_0-rmse:512.46868
# [245]	validation_0-rmse:512.37909
# [246]	validation_0-rmse:512.33100
# [247]	validation_0-rmse:512.35712
# [248]	validation_0-rmse:512.29959
# [249]	validation_0-rmse:512.16800
# [250]	validation_0-rmse:510.41172
# [251]	validation_0-rmse:510.32025
# [252]	validation_0-rmse:510.14323
# [253]	validation_0-rmse:509.99381
# [254]	validation_0-rmse:509.99936
# [255]	validation_0-rmse:510.04782
# [256]	validation_0-rmse:510.00533
# [257]	validation_0-rmse:509.73283
# [258]	validation_0-rmse:509.73833
# [259]	validation_0-rmse:509.39547
# [260]	validation_0-rmse:509.26105
# [261]	validation_0-rmse:509.15936
# [262]	validation_0-rmse:508.24490
# [263]	validation_0-rmse:508.13065
# [264]	validation_0-rmse:508.11485
# [265]	validation_0-rmse:507.79676
# [266]	validation_0-rmse:507.84940
# [267]	validation_0-rmse:507.75847
# [268]	validation_0-rmse:507.50492
# [269]	validation_0-rmse:506.72807
# [270]	validation_0-rmse:506.92213
# [271]	validation_0-rmse:506.85677
# [272]	validation_0-rmse:506.20729
# [273]	validation_0-rmse:506.16851
# [274]	validation_0-rmse:506.23981
# [275]	validation_0-rmse:506.17992
# [276]	validation_0-rmse:505.99671
# [277]	validation_0-rmse:504.97579
# [278]	validation_0-rmse:505.35110
# [279]	validation_0-rmse:505.28287
# [280]	validation_0-rmse:505.20160
# [281]	validation_0-rmse:505.23759
# [282]	validation_0-rmse:505.15264
# [283]	validation_0-rmse:505.34655
# [284]	validation_0-rmse:505.44663
# [285]	validation_0-rmse:505.35920
# [286]	validation_0-rmse:505.35338
# [287]	validation_0-rmse:505.22406
# [288]	validation_0-rmse:504.65520
# [289]	validation_0-rmse:504.54327
# [290]	validation_0-rmse:504.48054
# [291]	validation_0-rmse:504.34337
# [292]	validation_0-rmse:504.28830
# [293]	validation_0-rmse:503.79004
# [294]	validation_0-rmse:503.45516
# [295]	validation_0-rmse:503.28035
# [296]	validation_0-rmse:503.25065
# [297]	validation_0-rmse:503.20537
# [298]	validation_0-rmse:503.23497
# [299]	validation_0-rmse:503.22724
# [300]	validation_0-rmse:503.25783
# [301]	validation_0-rmse:503.11043
# [302]	validation_0-rmse:503.06646
# [303]	validation_0-rmse:503.05176
# [304]	validation_0-rmse:502.92507
# [305]	validation_0-rmse:502.86611
# [306]	validation_0-rmse:502.83061
# [307]	validation_0-rmse:502.11700
# [308]	validation_0-rmse:502.13183
# [309]	validation_0-rmse:502.14957
# [310]	validation_0-rmse:501.99672
# [311]	validation_0-rmse:501.78031
# [312]	validation_0-rmse:501.43982
# [313]	validation_0-rmse:501.35671
# [314]	validation_0-rmse:501.30395
# [315]	validation_0-rmse:501.14574
# [316]	validation_0-rmse:501.16214
# [317]	validation_0-rmse:501.15184
# [318]	validation_0-rmse:501.08696
# [319]	validation_0-rmse:501.05027
# [320]	validation_0-rmse:501.06521
# [321]	validation_0-rmse:500.98129
# [322]	validation_0-rmse:500.89194
# [323]	validation_0-rmse:500.92418
# [324]	validation_0-rmse:500.30354
# [325]	validation_0-rmse:500.19155
# [326]	validation_0-rmse:500.19232
# [327]	validation_0-rmse:500.31946
# [328]	validation_0-rmse:500.32878
# [329]	validation_0-rmse:500.26906
# [330]	validation_0-rmse:500.15542
# [331]	validation_0-rmse:500.03153
# [332]	validation_0-rmse:499.90296
# [333]	validation_0-rmse:499.70959
# [334]	validation_0-rmse:499.75249
# [335]	validation_0-rmse:499.70972
# [336]	validation_0-rmse:499.74292
# [337]	validation_0-rmse:499.71773
# [338]	validation_0-rmse:499.74394
# [339]	validation_0-rmse:499.67832
# [340]	validation_0-rmse:499.68369
# [341]	validation_0-rmse:499.26004
# [342]	validation_0-rmse:499.14283
# [343]	validation_0-rmse:499.14010
# [344]	validation_0-rmse:499.03533
# [345]	validation_0-rmse:498.98532
# [346]	validation_0-rmse:498.94583
# [347]	validation_0-rmse:498.97313
# [348]	validation_0-rmse:498.92379
# [349]	validation_0-rmse:498.91740
# [350]	validation_0-rmse:498.73527
# [351]	validation_0-rmse:498.72561
# [352]	validation_0-rmse:498.74424
# [353]	validation_0-rmse:498.17848
# [354]	validation_0-rmse:498.07724
# [355]	validation_0-rmse:497.94544
# [356]	validation_0-rmse:498.11349
# [357]	validation_0-rmse:498.03587
# [358]	validation_0-rmse:497.93560
# [359]	validation_0-rmse:497.76176
# [360]	validation_0-rmse:497.36223
# [361]	validation_0-rmse:497.33841
# [362]	validation_0-rmse:497.38070
# [363]	validation_0-rmse:497.41652
# [364]	validation_0-rmse:497.30623
# [365]	validation_0-rmse:497.19387
# [366]	validation_0-rmse:497.10481
# [367]	validation_0-rmse:497.13258
# [368]	validation_0-rmse:496.99382
# [369]	validation_0-rmse:497.07224
# [370]	validation_0-rmse:496.93212
# [371]	validation_0-rmse:496.85038
# [372]	validation_0-rmse:496.78047
# [373]	validation_0-rmse:496.75011
# [374]	validation_0-rmse:496.73003
# [375]	validation_0-rmse:497.02970
# [376]	validation_0-rmse:497.02931
# [377]	validation_0-rmse:497.06406
# [378]	validation_0-rmse:497.10891
# [379]	validation_0-rmse:497.13175
# [380]	validation_0-rmse:497.12974
# [381]	validation_0-rmse:496.97535
# [382]	validation_0-rmse:497.05342
# [383]	validation_0-rmse:496.81868
# [384]	validation_0-rmse:496.65370
# [385]	validation_0-rmse:496.76956
# [386]	validation_0-rmse:496.55068
# [387]	validation_0-rmse:496.37915
# [388]	validation_0-rmse:496.42888
# [389]	validation_0-rmse:496.39131
# [390]	validation_0-rmse:496.36248
# [391]	validation_0-rmse:496.38064
# [392]	validation_0-rmse:496.32766
# [393]	validation_0-rmse:496.37387
# [394]	validation_0-rmse:496.31920
# [395]	validation_0-rmse:496.29451
# [396]	validation_0-rmse:496.26416
# [397]	validation_0-rmse:496.27886
# [398]	validation_0-rmse:496.30314
# [399]	validation_0-rmse:495.50424
# [400]	validation_0-rmse:495.45854
# [401]	validation_0-rmse:495.35680
# [402]	validation_0-rmse:495.46592
# [403]	validation_0-rmse:495.32365
# [404]	validation_0-rmse:495.65425
# [405]	validation_0-rmse:495.69200
# [406]	validation_0-rmse:495.60174
# [407]	validation_0-rmse:495.18443
# [408]	validation_0-rmse:495.08596
# [409]	validation_0-rmse:493.98921
# [410]	validation_0-rmse:494.08651
# [411]	validation_0-rmse:494.08761
# [412]	validation_0-rmse:494.01601
# [413]	validation_0-rmse:494.01441
# [414]	validation_0-rmse:493.94857
# [415]	validation_0-rmse:493.85052
# [416]	validation_0-rmse:493.81402
# [417]	validation_0-rmse:493.84015
# [418]	validation_0-rmse:493.82895
# [419]	validation_0-rmse:494.37746
# [420]	validation_0-rmse:494.43083
# [421]	validation_0-rmse:494.39858
# [422]	validation_0-rmse:494.41129
# [423]	validation_0-rmse:494.34457
# [424]	validation_0-rmse:494.33576
# [425]	validation_0-rmse:494.41223
# [426]	validation_0-rmse:494.11605
# [427]	validation_0-rmse:494.22520
# [428]	validation_0-rmse:494.02358
# [429]	validation_0-rmse:493.98635
# [430]	validation_0-rmse:494.00773
# [431]	validation_0-rmse:494.10931
# [432]	validation_0-rmse:494.00134
# [433]	validation_0-rmse:493.81428
# [434]	validation_0-rmse:493.76925
# [435]	validation_0-rmse:493.72016
# [436]	validation_0-rmse:493.71093
# [437]	validation_0-rmse:493.68921
# [438]	validation_0-rmse:493.62289
# [439]	validation_0-rmse:493.64770
# [440]	validation_0-rmse:493.66864
# [441]	validation_0-rmse:493.66904
# [442]	validation_0-rmse:493.52821
# [443]	validation_0-rmse:493.42639
# [444]	validation_0-rmse:493.59861
# [445]	validation_0-rmse:493.63714
# [446]	validation_0-rmse:493.58199
# [447]	validation_0-rmse:493.66267
# [448]	validation_0-rmse:493.75082
# [449]	validation_0-rmse:493.60494
# [450]	validation_0-rmse:493.70152
# [451]	validation_0-rmse:493.71436
# [452]	validation_0-rmse:493.65366
# [453]	validation_0-rmse:493.67043
# [454]	validation_0-rmse:493.42498
# [455]	validation_0-rmse:493.59354
# [456]	validation_0-rmse:493.53285
# [457]	validation_0-rmse:493.44618
# [458]	validation_0-rmse:493.47415
# [459]	validation_0-rmse:493.41535
# [460]	validation_0-rmse:493.41846
# [461]	validation_0-rmse:493.16953
# [462]	validation_0-rmse:493.20203
# [463]	validation_0-rmse:493.03424
# [464]	validation_0-rmse:492.97092
# [465]	validation_0-rmse:493.03249
# [466]	validation_0-rmse:493.05279
# [467]	validation_0-rmse:492.92289
# [468]	validation_0-rmse:492.90973
# [469]	validation_0-rmse:492.79495
# [470]	validation_0-rmse:492.84922
# [471]	validation_0-rmse:492.90653
# [472]	validation_0-rmse:492.80553
# [473]	validation_0-rmse:492.68882
# [474]	validation_0-rmse:492.57323
# [475]	validation_0-rmse:492.58025
# [476]	validation_0-rmse:492.51159
# [477]	validation_0-rmse:492.56376
# [478]	validation_0-rmse:492.45934
# [479]	validation_0-rmse:492.63782
# [480]	validation_0-rmse:492.76234
# [481]	validation_0-rmse:492.48324
# [482]	validation_0-rmse:492.52121
# [483]	validation_0-rmse:492.51848
# [484]	validation_0-rmse:492.53236
# [485]	validation_0-rmse:492.30822
# [486]	validation_0-rmse:492.22292
# [487]	validation_0-rmse:492.15522
# [488]	validation_0-rmse:492.03429
# [489]	validation_0-rmse:492.27321
# [490]	validation_0-rmse:492.31554
# [491]	validation_0-rmse:492.31146
# [492]	validation_0-rmse:491.86245
# [493]	validation_0-rmse:491.81916
# [494]	validation_0-rmse:491.81941
# [495]	validation_0-rmse:491.81683
# [496]	validation_0-rmse:491.92710
# [497]	validation_0-rmse:492.01598
# [498]	validation_0-rmse:491.98637
# [499]	validation_0-rmse:492.00926
# [500]	validation_0-rmse:491.33146
# [501]	validation_0-rmse:491.40604
# [502]	validation_0-rmse:491.36610
# [503]	validation_0-rmse:491.34036
# [504]	validation_0-rmse:491.32368
# [505]	validation_0-rmse:491.24392
# [506]	validation_0-rmse:491.24099
# [507]	validation_0-rmse:491.10713
# [508]	validation_0-rmse:491.01430
# [509]	validation_0-rmse:491.19301
# [510]	validation_0-rmse:491.21155
# [511]	validation_0-rmse:490.76450
# [512]	validation_0-rmse:490.73093
# [513]	validation_0-rmse:490.64204
# [514]	validation_0-rmse:490.61259
# [515]	validation_0-rmse:490.14712
# [516]	validation_0-rmse:490.13406
# [517]	validation_0-rmse:490.05286
# [518]	validation_0-rmse:490.04004
# [519]	validation_0-rmse:490.06174
# [520]	validation_0-rmse:490.03648
# [521]	validation_0-rmse:490.09099
# [522]	validation_0-rmse:490.06885
# [523]	validation_0-rmse:490.19366
# [524]	validation_0-rmse:490.07282
# [525]	validation_0-rmse:489.84019
# [526]	validation_0-rmse:489.84212
# [527]	validation_0-rmse:489.79240
# [528]	validation_0-rmse:489.66526
# [529]	validation_0-rmse:489.63668
# [530]	validation_0-rmse:489.65148
# [531]	validation_0-rmse:489.65551
# [532]	validation_0-rmse:489.82265
# [533]	validation_0-rmse:489.79702
# [534]	validation_0-rmse:489.95659
# [535]	validation_0-rmse:489.83311
# [536]	validation_0-rmse:489.89123
# [537]	validation_0-rmse:489.89507
# [538]	validation_0-rmse:489.93044
# [539]	validation_0-rmse:489.91791
# [540]	validation_0-rmse:489.85954
# [541]	validation_0-rmse:489.89378
# [542]	validation_0-rmse:489.85477
# [543]	validation_0-rmse:489.84985
# [544]	validation_0-rmse:489.87620
# [545]	validation_0-rmse:489.77988
# [546]	validation_0-rmse:489.83470
# [547]	validation_0-rmse:489.82249
# [548]	validation_0-rmse:489.73467
# [549]	validation_0-rmse:489.69635
# [550]	validation_0-rmse:489.64696
# [551]	validation_0-rmse:489.60243
# [552]	validation_0-rmse:489.65770
# [553]	validation_0-rmse:489.66240
# [554]	validation_0-rmse:489.70953
# [555]	validation_0-rmse:489.81868
# [556]	validation_0-rmse:489.77165
# [557]	validation_0-rmse:489.72708
# [558]	validation_0-rmse:489.72436
# [559]	validation_0-rmse:489.70354
# [560]	validation_0-rmse:489.77397
# [561]	validation_0-rmse:489.84247
# [562]	validation_0-rmse:489.94594
# [563]	validation_0-rmse:489.90585
# [564]	validation_0-rmse:489.82835
# [565]	validation_0-rmse:489.79137
# [566]	validation_0-rmse:489.81643
# [567]	validation_0-rmse:489.88880
# [568]	validation_0-rmse:489.93837
# [569]	validation_0-rmse:489.89986
# [570]	validation_0-rmse:490.06368
# [571]	validation_0-rmse:489.98531
# [572]	validation_0-rmse:489.93443
# [573]	validation_0-rmse:489.98133
# [574]	validation_0-rmse:490.00119
# [575]	validation_0-rmse:490.06711
# [576]	validation_0-rmse:490.11729
# [577]	validation_0-rmse:489.99284
# [578]	validation_0-rmse:489.83999
# [579]	validation_0-rmse:489.65079
# [580]	validation_0-rmse:489.51197
# [581]	validation_0-rmse:489.45729
# [582]	validation_0-rmse:489.49092
# [583]	validation_0-rmse:489.50364
# [584]	validation_0-rmse:489.56719
# [585]	validation_0-rmse:489.57176
# [586]	validation_0-rmse:489.50109
# [587]	validation_0-rmse:489.55208
# [588]	validation_0-rmse:489.61429
# [589]	validation_0-rmse:489.13672
# [590]	validation_0-rmse:489.01403
# [591]	validation_0-rmse:488.84498
# [592]	validation_0-rmse:488.83653
# [593]	validation_0-rmse:488.83178
# [594]	validation_0-rmse:488.80989
# [595]	validation_0-rmse:488.78687
# [596]	validation_0-rmse:488.75232
# [597]	validation_0-rmse:488.76267
# [598]	validation_0-rmse:488.80277
# [599]	validation_0-rmse:488.71330
# [600]	validation_0-rmse:488.72324
# [601]	validation_0-rmse:488.64847
# [602]	validation_0-rmse:488.76164
# [603]	validation_0-rmse:488.77993
# [604]	validation_0-rmse:488.75390
# [605]	validation_0-rmse:488.72280
# [606]	validation_0-rmse:488.99984
# [607]	validation_0-rmse:489.05830
# [608]	validation_0-rmse:489.10538
# [609]	validation_0-rmse:489.10428
# [610]	validation_0-rmse:489.00298
# [611]	validation_0-rmse:488.90799
# [612]	validation_0-rmse:489.05823
# [613]	validation_0-rmse:489.03618
# [614]	validation_0-rmse:488.99322
# [615]	validation_0-rmse:488.97533
# [616]	validation_0-rmse:489.01874
# [617]	validation_0-rmse:488.97301
# [618]	validation_0-rmse:489.02415
# [619]	validation_0-rmse:489.04616
# [620]	validation_0-rmse:489.00679
# [621]	validation_0-rmse:489.04004
# [622]	validation_0-rmse:488.99442
# [623]	validation_0-rmse:489.09783
# [624]	validation_0-rmse:489.06468
# [625]	validation_0-rmse:489.08279
# [626]	validation_0-rmse:489.06497
# [627]	validation_0-rmse:489.07729
# [628]	validation_0-rmse:489.03569
# [629]	validation_0-rmse:488.93425
# [630]	validation_0-rmse:488.77241
# [631]	validation_0-rmse:488.81876
# [632]	validation_0-rmse:488.77813
# [633]	validation_0-rmse:488.73082
# [634]	validation_0-rmse:488.72861
# [635]	validation_0-rmse:488.74863
# [636]	validation_0-rmse:488.74668
# [637]	validation_0-rmse:488.70501
# [638]	validation_0-rmse:488.65495
# [639]	validation_0-rmse:488.60840
# [640]	validation_0-rmse:488.65761
# [641]	validation_0-rmse:488.75482
# [642]	validation_0-rmse:488.85972
# [643]	validation_0-rmse:488.81910
# [644]	validation_0-rmse:488.81867
# [645]	validation_0-rmse:488.82985
# [646]	validation_0-rmse:488.79175
# [647]	validation_0-rmse:488.78261
# [648]	validation_0-rmse:488.76776
# [649]	validation_0-rmse:488.87532
# [650]	validation_0-rmse:488.71553
# [651]	validation_0-rmse:488.69245
# [652]	validation_0-rmse:488.68473
# [653]	validation_0-rmse:488.62703
# [654]	validation_0-rmse:488.52807
# [655]	validation_0-rmse:488.60771
# [656]	validation_0-rmse:488.55154
# [657]	validation_0-rmse:488.54275
# [658]	validation_0-rmse:488.48696
# [659]	validation_0-rmse:488.50038
# [660]	validation_0-rmse:488.44403
# [661]	validation_0-rmse:488.46072
# [662]	validation_0-rmse:488.89299
# [663]	validation_0-rmse:488.86252
# [664]	validation_0-rmse:489.00911
# [665]	validation_0-rmse:489.25406
# [666]	validation_0-rmse:489.20870
# [667]	validation_0-rmse:489.17541
# [668]	validation_0-rmse:489.17351
# [669]	validation_0-rmse:489.09248
# [670]	validation_0-rmse:489.01303
# [671]	validation_0-rmse:488.55381
# [672]	validation_0-rmse:488.56176
# [673]	validation_0-rmse:488.51826
# [674]	validation_0-rmse:488.52421
# [675]	validation_0-rmse:488.50545
# [676]	validation_0-rmse:488.45990
# [677]	validation_0-rmse:488.42282
# [678]	validation_0-rmse:488.52605
# [679]	validation_0-rmse:488.43324
# [680]	validation_0-rmse:488.55387
# [681]	validation_0-rmse:488.58169
# [682]	validation_0-rmse:488.63551
# [683]	validation_0-rmse:488.60901
# [684]	validation_0-rmse:488.55708
# [685]	validation_0-rmse:488.57402
# [686]	validation_0-rmse:488.50693
# [687]	validation_0-rmse:488.48213
# [688]	validation_0-rmse:488.49051
# [689]	validation_0-rmse:488.43553
# [690]	validation_0-rmse:488.52465
# [691]	validation_0-rmse:488.64883
# [692]	validation_0-rmse:488.58899
# [693]	validation_0-rmse:488.59848
# [694]	validation_0-rmse:488.50986
# [695]	validation_0-rmse:488.43138
# [696]	validation_0-rmse:488.43769
# [697]	validation_0-rmse:488.43790
# [698]	validation_0-rmse:488.43011
# [699]	validation_0-rmse:488.43145
# [700]	validation_0-rmse:488.47388
# [701]	validation_0-rmse:488.40391
# [702]	validation_0-rmse:488.37537
# [703]	validation_0-rmse:488.44750
# [704]	validation_0-rmse:488.34120
# [705]	validation_0-rmse:488.37274
# [706]	validation_0-rmse:488.35782
# [707]	validation_0-rmse:488.48663
# [708]	validation_0-rmse:488.51450
# [709]	validation_0-rmse:488.57174
# [710]	validation_0-rmse:488.34230
# [711]	validation_0-rmse:488.38349
# [712]	validation_0-rmse:488.37582
# [713]	validation_0-rmse:488.37907
# [714]	validation_0-rmse:488.42482
# [715]	validation_0-rmse:488.46060
# [716]	validation_0-rmse:488.47281
# [717]	validation_0-rmse:488.52748
# [718]	validation_0-rmse:488.52969
# [719]	validation_0-rmse:488.55007
# [720]	validation_0-rmse:488.59122
# [721]	validation_0-rmse:488.59886
# [722]	validation_0-rmse:488.65925
# [723]	validation_0-rmse:488.53016
# [724]	validation_0-rmse:488.70336
# [725]	validation_0-rmse:488.72109
# [726]	validation_0-rmse:488.62701
# [727]	validation_0-rmse:488.63267
# [728]	validation_0-rmse:488.62065
# [729]	validation_0-rmse:488.66216
# [730]	validation_0-rmse:488.73871
# [731]	validation_0-rmse:488.67603
# [732]	validation_0-rmse:488.60618
# [733]	validation_0-rmse:488.63813
# [734]	validation_0-rmse:488.54062
# [735]	validation_0-rmse:488.53644
# [736]	validation_0-rmse:488.54482
# [737]	validation_0-rmse:488.50012
# [738]	validation_0-rmse:488.45767
# [739]	validation_0-rmse:488.47275
# [740]	validation_0-rmse:488.48020
# [741]	validation_0-rmse:488.48986
# [742]	validation_0-rmse:488.46138
# [743]	validation_0-rmse:488.55241
# [744]	validation_0-rmse:488.70004
# [745]	validation_0-rmse:488.70602
# [746]	validation_0-rmse:489.13799
# [747]	validation_0-rmse:489.08839
# [748]	validation_0-rmse:489.06540
# [749]	validation_0-rmse:489.28790
# [750]	validation_0-rmse:489.33021
# [751]	validation_0-rmse:489.29402
# [752]	validation_0-rmse:489.00522
# [753]	validation_0-rmse:488.94989
# [754]	validation_0-rmse:488.87932
#   Fold 1 RMSE: 488.3412
# [0]	validation_0-rmse:1213.32405
# [1]	validation_0-rmse:1171.08751
# [2]	validation_0-rmse:1132.24442
# [3]	validation_0-rmse:1091.20878
# [4]	validation_0-rmse:1055.11245
# [5]	validation_0-rmse:1020.68862
# [6]	validation_0-rmse:989.52870
# [7]	validation_0-rmse:964.12406
# [8]	validation_0-rmse:935.18207
# [9]	validation_0-rmse:910.44714
# [10]	validation_0-rmse:889.50145
# [11]	validation_0-rmse:867.87881
# [12]	validation_0-rmse:848.69339
# [13]	validation_0-rmse:828.77075
# [14]	validation_0-rmse:810.77814
# [15]	validation_0-rmse:795.60115
# [16]	validation_0-rmse:778.48184
# [17]	validation_0-rmse:766.62429
# [18]	validation_0-rmse:754.26804
# [19]	validation_0-rmse:742.82706
# [20]	validation_0-rmse:732.62853
# [21]	validation_0-rmse:722.53883
# [22]	validation_0-rmse:714.14296
# [23]	validation_0-rmse:705.03228
# [24]	validation_0-rmse:696.94929
# [25]	validation_0-rmse:690.15029
# [26]	validation_0-rmse:683.71165
# [27]	validation_0-rmse:677.51550
# [28]	validation_0-rmse:673.24492
# [29]	validation_0-rmse:668.77548
# [30]	validation_0-rmse:663.88149
# [31]	validation_0-rmse:658.41292
# [32]	validation_0-rmse:653.46127
# [33]	validation_0-rmse:649.85718
# [34]	validation_0-rmse:645.91978
# [35]	validation_0-rmse:642.72735
# [36]	validation_0-rmse:639.94848
# [37]	validation_0-rmse:636.14458
# [38]	validation_0-rmse:633.78283
# [39]	validation_0-rmse:630.85227
# [40]	validation_0-rmse:628.13842
# [41]	validation_0-rmse:625.79871
# [42]	validation_0-rmse:624.24177
# [43]	validation_0-rmse:622.60455
# [44]	validation_0-rmse:621.48408
# [45]	validation_0-rmse:620.15715
# [46]	validation_0-rmse:619.08891
# [47]	validation_0-rmse:617.91997
# [48]	validation_0-rmse:616.64650
# [49]	validation_0-rmse:614.91473
# [50]	validation_0-rmse:613.51014
# [51]	validation_0-rmse:612.80042
# [52]	validation_0-rmse:612.01675
# [53]	validation_0-rmse:610.69676
# [54]	validation_0-rmse:609.75723
# [55]	validation_0-rmse:608.81741
# [56]	validation_0-rmse:607.80875
# [57]	validation_0-rmse:606.43986
# [58]	validation_0-rmse:605.48617
# [59]	validation_0-rmse:604.41240
# [60]	validation_0-rmse:603.32933
# [61]	validation_0-rmse:602.81467
# [62]	validation_0-rmse:601.71100
# [63]	validation_0-rmse:601.67227
# [64]	validation_0-rmse:600.47737
# [65]	validation_0-rmse:600.82268
# [66]	validation_0-rmse:599.99187
# [67]	validation_0-rmse:599.07553
# [68]	validation_0-rmse:598.90034
# [69]	validation_0-rmse:598.10038
# [70]	validation_0-rmse:598.93679
# [71]	validation_0-rmse:598.45290
# [72]	validation_0-rmse:598.38445
# [73]	validation_0-rmse:598.04329
# [74]	validation_0-rmse:597.49817
# [75]	validation_0-rmse:596.88134
# [76]	validation_0-rmse:595.69384
# [77]	validation_0-rmse:594.99301
# [78]	validation_0-rmse:594.64140
# [79]	validation_0-rmse:593.85325
# [80]	validation_0-rmse:593.03479
# [81]	validation_0-rmse:591.92233
# [82]	validation_0-rmse:591.27359
# [83]	validation_0-rmse:590.82818
# [84]	validation_0-rmse:590.23071
# [85]	validation_0-rmse:589.37706
# [86]	validation_0-rmse:589.22640
# [87]	validation_0-rmse:588.65366
# [88]	validation_0-rmse:588.29183
# [89]	validation_0-rmse:587.78706
# [90]	validation_0-rmse:587.42448
# [91]	validation_0-rmse:586.93076
# [92]	validation_0-rmse:586.27716
# [93]	validation_0-rmse:585.80028
# [94]	validation_0-rmse:585.50263
# [95]	validation_0-rmse:585.09126
# [96]	validation_0-rmse:584.61027
# [97]	validation_0-rmse:583.64835
# [98]	validation_0-rmse:583.31857
# [99]	validation_0-rmse:582.86792
# [100]	validation_0-rmse:582.70167
# [101]	validation_0-rmse:582.43796
# [102]	validation_0-rmse:581.92393
# [103]	validation_0-rmse:581.80767
# [104]	validation_0-rmse:581.75660
# [105]	validation_0-rmse:581.28933
# [106]	validation_0-rmse:580.59583
# [107]	validation_0-rmse:580.32608
# [108]	validation_0-rmse:580.11759
# [109]	validation_0-rmse:579.53747
# [110]	validation_0-rmse:579.31158
# [111]	validation_0-rmse:578.89302
# [112]	validation_0-rmse:578.51032
# [113]	validation_0-rmse:578.18952
# [114]	validation_0-rmse:577.75217
# [115]	validation_0-rmse:577.44451
# [116]	validation_0-rmse:577.14089
# [117]	validation_0-rmse:576.84830
# [118]	validation_0-rmse:576.78211
# [119]	validation_0-rmse:577.75601
# [120]	validation_0-rmse:577.46409
# [121]	validation_0-rmse:577.22903
# [122]	validation_0-rmse:577.03896
# [123]	validation_0-rmse:577.21615
# [124]	validation_0-rmse:576.95210
# [125]	validation_0-rmse:576.62406
# [126]	validation_0-rmse:576.32345
# [127]	validation_0-rmse:576.04899
# [128]	validation_0-rmse:575.63289
# [129]	validation_0-rmse:575.53269
# [130]	validation_0-rmse:575.30537
# [131]	validation_0-rmse:574.87936
# [132]	validation_0-rmse:574.65853
# [133]	validation_0-rmse:574.23544
# [134]	validation_0-rmse:573.90957
# [135]	validation_0-rmse:575.24472
# [136]	validation_0-rmse:575.56372
# [137]	validation_0-rmse:575.37544
# [138]	validation_0-rmse:575.29665
# [139]	validation_0-rmse:575.69738
# [140]	validation_0-rmse:575.62202
# [141]	validation_0-rmse:577.64240
# [142]	validation_0-rmse:577.37587
# [143]	validation_0-rmse:577.24229
# [144]	validation_0-rmse:577.07412
# [145]	validation_0-rmse:576.83612
# [146]	validation_0-rmse:576.17963
# [147]	validation_0-rmse:575.96599
# [148]	validation_0-rmse:575.68419
# [149]	validation_0-rmse:575.64284
# [150]	validation_0-rmse:575.48672
# [151]	validation_0-rmse:575.27262
# [152]	validation_0-rmse:574.68757
# [153]	validation_0-rmse:574.38805
# [154]	validation_0-rmse:574.23076
# [155]	validation_0-rmse:574.11206
# [156]	validation_0-rmse:573.99302
# [157]	validation_0-rmse:574.28306
# [158]	validation_0-rmse:574.00592
# [159]	validation_0-rmse:573.83433
# [160]	validation_0-rmse:573.51733
# [161]	validation_0-rmse:574.37861
# [162]	validation_0-rmse:574.24548
# [163]	validation_0-rmse:574.01385
# [164]	validation_0-rmse:573.95030
# [165]	validation_0-rmse:573.76570
# [166]	validation_0-rmse:573.65474
# [167]	validation_0-rmse:573.45281
# [168]	validation_0-rmse:573.53058
# [169]	validation_0-rmse:573.41684
# [170]	validation_0-rmse:573.39627
# [171]	validation_0-rmse:573.42776
# [172]	validation_0-rmse:573.33637
# [173]	validation_0-rmse:573.09378
# [174]	validation_0-rmse:573.74666
# [175]	validation_0-rmse:573.57837
# [176]	validation_0-rmse:573.51130
# [177]	validation_0-rmse:573.36643
# [178]	validation_0-rmse:573.31919
# [179]	validation_0-rmse:573.21277
# [180]	validation_0-rmse:572.97111
# [181]	validation_0-rmse:572.71177
# [182]	validation_0-rmse:572.56247
# [183]	validation_0-rmse:572.62465
# [184]	validation_0-rmse:572.63325
# [185]	validation_0-rmse:572.37403
# [186]	validation_0-rmse:572.31625
# [187]	validation_0-rmse:572.25444
# [188]	validation_0-rmse:572.21859
# [189]	validation_0-rmse:572.11425
# [190]	validation_0-rmse:571.92208
# [191]	validation_0-rmse:571.90774
# [192]	validation_0-rmse:571.85674
# [193]	validation_0-rmse:571.78974
# [194]	validation_0-rmse:571.87528
# [195]	validation_0-rmse:571.83408
# [196]	validation_0-rmse:571.57615
# [197]	validation_0-rmse:571.37014
# [198]	validation_0-rmse:571.14068
# [199]	validation_0-rmse:570.80641
# [200]	validation_0-rmse:570.59930
# [201]	validation_0-rmse:570.52115
# [202]	validation_0-rmse:570.45469
# [203]	validation_0-rmse:570.34569
# [204]	validation_0-rmse:569.90135
# [205]	validation_0-rmse:569.76105
# [206]	validation_0-rmse:569.80537
# [207]	validation_0-rmse:570.25819
# [208]	validation_0-rmse:570.22731
# [209]	validation_0-rmse:570.15711
# [210]	validation_0-rmse:569.90724
# [211]	validation_0-rmse:569.95143
# [212]	validation_0-rmse:569.75202
# [213]	validation_0-rmse:569.62063
# [214]	validation_0-rmse:569.98035
# [215]	validation_0-rmse:569.92164
# [216]	validation_0-rmse:570.00282
# [217]	validation_0-rmse:570.31403
# [218]	validation_0-rmse:570.00411
# [219]	validation_0-rmse:569.92158
# [220]	validation_0-rmse:569.88905
# [221]	validation_0-rmse:569.76702
# [222]	validation_0-rmse:569.19423
# [223]	validation_0-rmse:569.19303
# [224]	validation_0-rmse:569.27032
# [225]	validation_0-rmse:569.00523
# [226]	validation_0-rmse:568.91794
# [227]	validation_0-rmse:568.97389
# [228]	validation_0-rmse:569.10910
# [229]	validation_0-rmse:568.96825
# [230]	validation_0-rmse:568.86302
# [231]	validation_0-rmse:568.66473
# [232]	validation_0-rmse:568.46471
# [233]	validation_0-rmse:568.20373
# [234]	validation_0-rmse:568.11514
# [235]	validation_0-rmse:568.05825
# [236]	validation_0-rmse:567.97912
# [237]	validation_0-rmse:567.87656
# [238]	validation_0-rmse:567.69303
# [239]	validation_0-rmse:567.67835
# [240]	validation_0-rmse:567.74939
# [241]	validation_0-rmse:567.87619
# [242]	validation_0-rmse:568.05939
# [243]	validation_0-rmse:568.13677
# [244]	validation_0-rmse:568.20199
# [245]	validation_0-rmse:568.90125
# [246]	validation_0-rmse:568.84839
# [247]	validation_0-rmse:568.74391
# [248]	validation_0-rmse:568.64461
# [249]	validation_0-rmse:568.64897
# [250]	validation_0-rmse:568.51279
# [251]	validation_0-rmse:569.45458
# [252]	validation_0-rmse:569.34062
# [253]	validation_0-rmse:569.02619
# [254]	validation_0-rmse:569.03721
# [255]	validation_0-rmse:568.97332
# [256]	validation_0-rmse:568.95092
# [257]	validation_0-rmse:568.95862
# [258]	validation_0-rmse:568.83908
# [259]	validation_0-rmse:568.96807
# [260]	validation_0-rmse:569.03922
# [261]	validation_0-rmse:569.26927
# [262]	validation_0-rmse:569.56236
# [263]	validation_0-rmse:569.75699
# [264]	validation_0-rmse:569.87846
# [265]	validation_0-rmse:569.82076
# [266]	validation_0-rmse:570.14432
# [267]	validation_0-rmse:569.99118
# [268]	validation_0-rmse:569.96745
# [269]	validation_0-rmse:569.93854
# [270]	validation_0-rmse:569.95222
# [271]	validation_0-rmse:569.83087
# [272]	validation_0-rmse:569.76614
# [273]	validation_0-rmse:569.86510
# [274]	validation_0-rmse:569.83269
# [275]	validation_0-rmse:569.80387
# [276]	validation_0-rmse:569.77104
# [277]	validation_0-rmse:569.77350
# [278]	validation_0-rmse:569.72608
# [279]	validation_0-rmse:569.68485
# [280]	validation_0-rmse:569.47147
# [281]	validation_0-rmse:569.39799
# [282]	validation_0-rmse:569.35803
# [283]	validation_0-rmse:569.32330
# [284]	validation_0-rmse:569.31102
# [285]	validation_0-rmse:569.53950
# [286]	validation_0-rmse:569.25460
# [287]	validation_0-rmse:569.26361
# [288]	validation_0-rmse:569.27270
#   Fold 2 RMSE: 567.6783
# [0]	validation_0-rmse:1144.78976
# [1]	validation_0-rmse:1112.12944
# [2]	validation_0-rmse:1079.91898
# [3]	validation_0-rmse:1048.62683
# [4]	validation_0-rmse:1020.74071
# [5]	validation_0-rmse:993.04063
# [6]	validation_0-rmse:967.67303
# [7]	validation_0-rmse:944.22752
# [8]	validation_0-rmse:920.22847
# [9]	validation_0-rmse:899.18116
# [10]	validation_0-rmse:878.45855
# [11]	validation_0-rmse:858.89300
# [12]	validation_0-rmse:839.57892
# [13]	validation_0-rmse:822.33229
# [14]	validation_0-rmse:806.32919
# [15]	validation_0-rmse:790.42743
# [16]	validation_0-rmse:773.72375
# [17]	validation_0-rmse:760.44241
# [18]	validation_0-rmse:747.85684
# [19]	validation_0-rmse:735.29692
# [20]	validation_0-rmse:723.96053
# [21]	validation_0-rmse:711.66424
# [22]	validation_0-rmse:699.41207
# [23]	validation_0-rmse:688.58766
# [24]	validation_0-rmse:678.61518
# [25]	validation_0-rmse:668.82861
# [26]	validation_0-rmse:659.87265
# [27]	validation_0-rmse:651.68941
# [28]	validation_0-rmse:643.92059
# [29]	validation_0-rmse:636.41465
# [30]	validation_0-rmse:628.45635
# [31]	validation_0-rmse:620.48772
# [32]	validation_0-rmse:614.35779
# [33]	validation_0-rmse:608.29705
# [34]	validation_0-rmse:602.54110
# [35]	validation_0-rmse:595.56193
# [36]	validation_0-rmse:590.34776
# [37]	validation_0-rmse:584.21399
# [38]	validation_0-rmse:578.13316
# [39]	validation_0-rmse:573.15443
# [40]	validation_0-rmse:568.74403
# [41]	validation_0-rmse:564.05079
# [42]	validation_0-rmse:559.33289
# [43]	validation_0-rmse:555.71627
# [44]	validation_0-rmse:552.03046
# [45]	validation_0-rmse:547.06871
# [46]	validation_0-rmse:543.76787
# [47]	validation_0-rmse:539.61065
# [48]	validation_0-rmse:536.44896
# [49]	validation_0-rmse:533.22216
# [50]	validation_0-rmse:530.88704
# [51]	validation_0-rmse:527.73856
# [52]	validation_0-rmse:525.62493
# [53]	validation_0-rmse:523.14157
# [54]	validation_0-rmse:519.51829
# [55]	validation_0-rmse:517.07343
# [56]	validation_0-rmse:515.02836
# [57]	validation_0-rmse:513.01320
# [58]	validation_0-rmse:510.65063
# [59]	validation_0-rmse:508.61422
# [60]	validation_0-rmse:507.04900
# [61]	validation_0-rmse:505.30796
# [62]	validation_0-rmse:502.89348
# [63]	validation_0-rmse:500.68090
# [64]	validation_0-rmse:498.82342
# [65]	validation_0-rmse:496.98386
# [66]	validation_0-rmse:495.55727
# [67]	validation_0-rmse:493.04344
# [68]	validation_0-rmse:491.55714
# [69]	validation_0-rmse:489.99017
# [70]	validation_0-rmse:488.49522
# [71]	validation_0-rmse:487.13044
# [72]	validation_0-rmse:485.75760
# [73]	validation_0-rmse:483.66848
# [74]	validation_0-rmse:482.09713
# [75]	validation_0-rmse:481.18545
# [76]	validation_0-rmse:478.84334
# [77]	validation_0-rmse:476.61527
# [78]	validation_0-rmse:475.49069
# [79]	validation_0-rmse:473.81490
# [80]	validation_0-rmse:472.79829
# [81]	validation_0-rmse:472.26544
# [82]	validation_0-rmse:471.04610
# [83]	validation_0-rmse:470.13238
# [84]	validation_0-rmse:468.57965
# [85]	validation_0-rmse:467.11556
# [86]	validation_0-rmse:466.90893
# [87]	validation_0-rmse:465.26436
# [88]	validation_0-rmse:464.00010
# [89]	validation_0-rmse:463.08111
# [90]	validation_0-rmse:461.85632
# [91]	validation_0-rmse:461.16361
# [92]	validation_0-rmse:459.99835
# [93]	validation_0-rmse:458.68695
# [94]	validation_0-rmse:457.89666
# [95]	validation_0-rmse:457.04343
# [96]	validation_0-rmse:456.41875
# [97]	validation_0-rmse:455.47189
# [98]	validation_0-rmse:454.85347
# [99]	validation_0-rmse:453.85548
# [100]	validation_0-rmse:452.85402
# [101]	validation_0-rmse:452.12730
# [102]	validation_0-rmse:450.85867
# [103]	validation_0-rmse:450.39306
# [104]	validation_0-rmse:449.75095
# [105]	validation_0-rmse:448.87417
# [106]	validation_0-rmse:448.30827
# [107]	validation_0-rmse:447.66320
# [108]	validation_0-rmse:446.83383
# [109]	validation_0-rmse:445.49205
# [110]	validation_0-rmse:445.09452
# [111]	validation_0-rmse:444.74494
# [112]	validation_0-rmse:443.81974
# [113]	validation_0-rmse:443.27953
# [114]	validation_0-rmse:442.64459
# [115]	validation_0-rmse:442.02867
# [116]	validation_0-rmse:441.67879
# [117]	validation_0-rmse:441.02010
# [118]	validation_0-rmse:440.61632
# [119]	validation_0-rmse:440.27371
# [120]	validation_0-rmse:439.83112
# [121]	validation_0-rmse:438.60875
# [122]	validation_0-rmse:437.93017
# [123]	validation_0-rmse:437.19890
# [124]	validation_0-rmse:436.33321
# [125]	validation_0-rmse:435.89806
# [126]	validation_0-rmse:435.46356
# [127]	validation_0-rmse:435.08106
# [128]	validation_0-rmse:434.07484
# [129]	validation_0-rmse:433.29367
# [130]	validation_0-rmse:433.15806
# [131]	validation_0-rmse:432.78470
# [132]	validation_0-rmse:431.84668
# [133]	validation_0-rmse:431.39344
# [134]	validation_0-rmse:430.34244
# [135]	validation_0-rmse:430.06119
# [136]	validation_0-rmse:429.64302
# [137]	validation_0-rmse:429.02889
# [138]	validation_0-rmse:428.65935
# [139]	validation_0-rmse:427.80255
# [140]	validation_0-rmse:427.29184
# [141]	validation_0-rmse:427.09576
# [142]	validation_0-rmse:426.76479
# [143]	validation_0-rmse:426.34185
# [144]	validation_0-rmse:425.71059
# [145]	validation_0-rmse:425.34934
# [146]	validation_0-rmse:424.98434
# [147]	validation_0-rmse:424.57819
# [148]	validation_0-rmse:424.30001
# [149]	validation_0-rmse:423.80381
# [150]	validation_0-rmse:423.27952
# [151]	validation_0-rmse:422.84913
# [152]	validation_0-rmse:422.09091
# [153]	validation_0-rmse:421.44940
# [154]	validation_0-rmse:420.96300
# [155]	validation_0-rmse:420.41050
# [156]	validation_0-rmse:420.10848
# [157]	validation_0-rmse:419.61506
# [158]	validation_0-rmse:419.03727
# [159]	validation_0-rmse:418.18314
# [160]	validation_0-rmse:418.03738
# [161]	validation_0-rmse:417.85478
# [162]	validation_0-rmse:417.46237
# [163]	validation_0-rmse:417.09566
# [164]	validation_0-rmse:416.86034
# [165]	validation_0-rmse:416.58529
# [166]	validation_0-rmse:416.26613
# [167]	validation_0-rmse:415.96196
# [168]	validation_0-rmse:415.59693
# [169]	validation_0-rmse:415.12704
# [170]	validation_0-rmse:415.08456
# [171]	validation_0-rmse:415.00542
# [172]	validation_0-rmse:414.73463
# [173]	validation_0-rmse:414.26382
# [174]	validation_0-rmse:414.29037
# [175]	validation_0-rmse:414.11832
# [176]	validation_0-rmse:413.80369
# [177]	validation_0-rmse:413.57906
# [178]	validation_0-rmse:413.39948
# [179]	validation_0-rmse:413.06760
# [180]	validation_0-rmse:412.83248
# [181]	validation_0-rmse:412.67975
# [182]	validation_0-rmse:412.32158
# [183]	validation_0-rmse:412.10356
# [184]	validation_0-rmse:411.82863
# [185]	validation_0-rmse:411.61868
# [186]	validation_0-rmse:411.49336
# [187]	validation_0-rmse:411.33806
# [188]	validation_0-rmse:410.89099
# [189]	validation_0-rmse:410.70932
# [190]	validation_0-rmse:410.58778
# [191]	validation_0-rmse:410.37042
# [192]	validation_0-rmse:410.08044
# [193]	validation_0-rmse:409.88864
# [194]	validation_0-rmse:409.68712
# [195]	validation_0-rmse:409.52938
# [196]	validation_0-rmse:409.35236
# [197]	validation_0-rmse:408.88156
# [198]	validation_0-rmse:408.70824
# [199]	validation_0-rmse:408.49677
# [200]	validation_0-rmse:408.24961
# [201]	validation_0-rmse:408.11298
# [202]	validation_0-rmse:407.90268
# [203]	validation_0-rmse:407.74209
# [204]	validation_0-rmse:407.47903
# [205]	validation_0-rmse:407.13496
# [206]	validation_0-rmse:407.01709
# [207]	validation_0-rmse:406.68995
# [208]	validation_0-rmse:406.45231
# [209]	validation_0-rmse:406.31950
# [210]	validation_0-rmse:406.36941
# [211]	validation_0-rmse:406.21993
# [212]	validation_0-rmse:405.92716
# [213]	validation_0-rmse:405.88594
# [214]	validation_0-rmse:405.76540
# [215]	validation_0-rmse:405.34986
# [216]	validation_0-rmse:405.29333
# [217]	validation_0-rmse:404.92979
# [218]	validation_0-rmse:404.74717
# [219]	validation_0-rmse:404.59560
# [220]	validation_0-rmse:404.48017
# [221]	validation_0-rmse:404.30055
# [222]	validation_0-rmse:404.22893
# [223]	validation_0-rmse:404.09170
# [224]	validation_0-rmse:403.81916
# [225]	validation_0-rmse:403.75153
# [226]	validation_0-rmse:403.58859
# [227]	validation_0-rmse:403.46273
# [228]	validation_0-rmse:403.18684
# [229]	validation_0-rmse:403.02856
# [230]	validation_0-rmse:402.93811
# [231]	validation_0-rmse:402.62563
# [232]	validation_0-rmse:402.19393
# [233]	validation_0-rmse:402.01666
# [234]	validation_0-rmse:401.93575
# [235]	validation_0-rmse:401.71600
# [236]	validation_0-rmse:401.71392
# [237]	validation_0-rmse:401.27678
# [238]	validation_0-rmse:401.45823
# [239]	validation_0-rmse:401.24770
# [240]	validation_0-rmse:401.16708
# [241]	validation_0-rmse:400.91440
# [242]	validation_0-rmse:400.67117
# [243]	validation_0-rmse:400.51869
# [244]	validation_0-rmse:400.06660
# [245]	validation_0-rmse:399.93195
# [246]	validation_0-rmse:399.82267
# [247]	validation_0-rmse:399.65031
# [248]	validation_0-rmse:399.56006
# [249]	validation_0-rmse:399.47403
# [250]	validation_0-rmse:399.40547
# [251]	validation_0-rmse:399.32726
# [252]	validation_0-rmse:399.16573
# [253]	validation_0-rmse:398.95677
# [254]	validation_0-rmse:398.75776
# [255]	validation_0-rmse:398.53801
# [256]	validation_0-rmse:398.46940
# [257]	validation_0-rmse:398.34159
# [258]	validation_0-rmse:398.24578
# [259]	validation_0-rmse:398.11738
# [260]	validation_0-rmse:397.93074
# [261]	validation_0-rmse:397.71763
# [262]	validation_0-rmse:397.77725
# [263]	validation_0-rmse:397.72699
# [264]	validation_0-rmse:397.55583
# [265]	validation_0-rmse:397.42655
# [266]	validation_0-rmse:397.40242
# [267]	validation_0-rmse:397.19363
# [268]	validation_0-rmse:397.25020
# [269]	validation_0-rmse:397.18206
# [270]	validation_0-rmse:396.85991
# [271]	validation_0-rmse:396.70950
# [272]	validation_0-rmse:396.57115
# [273]	validation_0-rmse:396.45985
# [274]	validation_0-rmse:396.37154
# [275]	validation_0-rmse:396.28549
# [276]	validation_0-rmse:396.20633
# [277]	validation_0-rmse:396.10286
# [278]	validation_0-rmse:396.01165
# [279]	validation_0-rmse:395.94152
# [280]	validation_0-rmse:395.87521
# [281]	validation_0-rmse:395.78432
# [282]	validation_0-rmse:395.76678
# [283]	validation_0-rmse:395.81208
# [284]	validation_0-rmse:395.67336
# [285]	validation_0-rmse:395.57433
# [286]	validation_0-rmse:395.38663
# [287]	validation_0-rmse:395.24624
# [288]	validation_0-rmse:395.20252
# [289]	validation_0-rmse:394.94087
# [290]	validation_0-rmse:394.76481
# [291]	validation_0-rmse:394.66468
# [292]	validation_0-rmse:394.70616
# [293]	validation_0-rmse:394.60533
# [294]	validation_0-rmse:394.40643
# [295]	validation_0-rmse:394.27000
# [296]	validation_0-rmse:394.14116
# [297]	validation_0-rmse:394.09856
# [298]	validation_0-rmse:393.71407
# [299]	validation_0-rmse:393.68502
# [300]	validation_0-rmse:393.60396
# [301]	validation_0-rmse:393.39905
# [302]	validation_0-rmse:393.28126
# [303]	validation_0-rmse:393.20395
# [304]	validation_0-rmse:393.13771
# [305]	validation_0-rmse:392.95602
# [306]	validation_0-rmse:392.80723
# [307]	validation_0-rmse:392.64208
# [308]	validation_0-rmse:392.57321
# [309]	validation_0-rmse:392.55219
# [310]	validation_0-rmse:392.31304
# [311]	validation_0-rmse:392.29270
# [312]	validation_0-rmse:392.35465
# [313]	validation_0-rmse:392.27200
# [314]	validation_0-rmse:392.26411
# [315]	validation_0-rmse:392.01882
# [316]	validation_0-rmse:391.85868
# [317]	validation_0-rmse:391.89251
# [318]	validation_0-rmse:391.87316
# [319]	validation_0-rmse:391.81760
# [320]	validation_0-rmse:391.73459
# [321]	validation_0-rmse:391.66406
# [322]	validation_0-rmse:391.58776
# [323]	validation_0-rmse:391.50913
# [324]	validation_0-rmse:391.43972
# [325]	validation_0-rmse:391.35765
# [326]	validation_0-rmse:390.97795
# [327]	validation_0-rmse:390.77342
# [328]	validation_0-rmse:390.75848
# [329]	validation_0-rmse:390.57178
# [330]	validation_0-rmse:390.40090
# [331]	validation_0-rmse:390.19731
# [332]	validation_0-rmse:390.10775
# [333]	validation_0-rmse:390.11655
# [334]	validation_0-rmse:390.08504
# [335]	validation_0-rmse:389.99812
# [336]	validation_0-rmse:389.90575
# [337]	validation_0-rmse:389.81893
# [338]	validation_0-rmse:389.66109
# [339]	validation_0-rmse:389.60885
# [340]	validation_0-rmse:389.54268
# [341]	validation_0-rmse:389.49304
# [342]	validation_0-rmse:389.41197
# [343]	validation_0-rmse:389.30555
# [344]	validation_0-rmse:389.28124
# [345]	validation_0-rmse:389.19505
# [346]	validation_0-rmse:389.04565
# [347]	validation_0-rmse:389.01330
# [348]	validation_0-rmse:388.94865
# [349]	validation_0-rmse:388.91877
# [350]	validation_0-rmse:388.79946
# [351]	validation_0-rmse:388.78091
# [352]	validation_0-rmse:388.70919
# [353]	validation_0-rmse:388.61880
# [354]	validation_0-rmse:388.51597
# [355]	validation_0-rmse:388.18542
# [356]	validation_0-rmse:388.03333
# [357]	validation_0-rmse:387.97067
# [358]	validation_0-rmse:387.89832
# [359]	validation_0-rmse:387.79700
# [360]	validation_0-rmse:387.78906
# ...
# [180]	validation_0-rmse:546.58871
# [181]	validation_0-rmse:546.51052
# [182]	validation_0-rmse:546.33581
# [183]	validation_0-rmse:546.00388
# [184]	validation_0-rmse:545.74166
# [185]	validation_0-rmse:545.74170
# [186]	validation_0-rmse:546.05914
# [187]	validation_0-rmse:545.85507
# [188]	validation_0-rmse:545.69603
# [189]	validation_0-rmse:545.12950
# [190]	validation_0-rmse:545.00337
# [191]	validation_0-rmse:544.62136
# [192]	validation_0-rmse:544.10728
# [193]	validation_0-rmse:543.69829
# [194]	validation_0-rmse:543.49691
# [195]	validation_0-rmse:543.03743
# [196]	validation_0-rmse:543.02703
# [197]	validation_0-rmse:542.76000
# [198]	validation_0-rmse:542.50019
# [199]	validation_0-rmse:542.33421
# [200]	validation_0-rmse:542.21303
# [201]	validation_0-rmse:541.74520
# [202]	validation_0-rmse:541.65189
# [203]	validation_0-rmse:541.50536
# [204]	validation_0-rmse:541.19605
# [205]	validation_0-rmse:541.05654
# [206]	validation_0-rmse:540.75592
# [207]	validation_0-rmse:540.67203
# [208]	validation_0-rmse:540.26400
# [209]	validation_0-rmse:540.47872
# [210]	validation_0-rmse:540.34725
# [211]	validation_0-rmse:540.18521
# [212]	validation_0-rmse:540.11553
# [213]	validation_0-rmse:539.90264
# [214]	validation_0-rmse:539.51411
# [215]	validation_0-rmse:539.05937
# [216]	validation_0-rmse:538.62655
# [217]	validation_0-rmse:538.45297
# [218]	validation_0-rmse:538.21298
# [219]	validation_0-rmse:537.99990
# [220]	validation_0-rmse:537.74688
# [221]	validation_0-rmse:537.42421
# [222]	validation_0-rmse:537.29135
# [223]	validation_0-rmse:537.48254
# [224]	validation_0-rmse:537.29067
# [225]	validation_0-rmse:537.11954
# [226]	validation_0-rmse:536.82307
# [227]	validation_0-rmse:536.69068
# [228]	validation_0-rmse:536.52283
# [229]	validation_0-rmse:536.25473
# [230]	validation_0-rmse:536.08435
# [231]	validation_0-rmse:536.70780
# [232]	validation_0-rmse:536.41539
# [233]	validation_0-rmse:536.38755
# [234]	validation_0-rmse:536.13844
# [235]	validation_0-rmse:537.43312
# [236]	validation_0-rmse:537.30856
# [237]	validation_0-rmse:537.11990
# [238]	validation_0-rmse:536.90748
# [239]	validation_0-rmse:536.56223
# [240]	validation_0-rmse:536.88169
# [241]	validation_0-rmse:536.30824
# [242]	validation_0-rmse:536.05240
# [243]	validation_0-rmse:535.82994
# [244]	validation_0-rmse:535.45473
# [245]	validation_0-rmse:534.58143
# [246]	validation_0-rmse:534.52991
# [247]	validation_0-rmse:534.44918
# [248]	validation_0-rmse:534.07976
# [249]	validation_0-rmse:533.93589
# [250]	validation_0-rmse:533.08515
# [251]	validation_0-rmse:532.73599
# [252]	validation_0-rmse:532.56549
# [253]	validation_0-rmse:532.34873
# [254]	validation_0-rmse:532.26493
# [255]	validation_0-rmse:532.41457
# [256]	validation_0-rmse:532.19527
# [257]	validation_0-rmse:532.08385
# [258]	validation_0-rmse:531.92930
# [259]	validation_0-rmse:531.77989
# [260]	validation_0-rmse:531.79745
# [261]	validation_0-rmse:531.63930
# [262]	validation_0-rmse:531.55096
# [263]	validation_0-rmse:531.44814
# [264]	validation_0-rmse:531.18996
# [265]	validation_0-rmse:531.01272
# [266]	validation_0-rmse:530.69894
# [267]	validation_0-rmse:530.38271
# [268]	validation_0-rmse:530.39487
# [269]	validation_0-rmse:530.29056
# [270]	validation_0-rmse:530.13614
# [271]	validation_0-rmse:529.88070
# [272]	validation_0-rmse:529.78519
# [273]	validation_0-rmse:529.69184
# [274]	validation_0-rmse:529.51283
# [275]	validation_0-rmse:529.77536
# [276]	validation_0-rmse:529.72363
# [277]	validation_0-rmse:529.63872
# [278]	validation_0-rmse:528.84668
# [279]	validation_0-rmse:528.79269
# [280]	validation_0-rmse:528.88265
# [281]	validation_0-rmse:528.65419
# [282]	validation_0-rmse:528.28272
# [283]	validation_0-rmse:528.08950
# [284]	validation_0-rmse:528.14194
# [285]	validation_0-rmse:527.90248
# [286]	validation_0-rmse:527.56577
# [287]	validation_0-rmse:527.48373
# [288]	validation_0-rmse:527.30095
# [289]	validation_0-rmse:526.95538
# [290]	validation_0-rmse:526.84431
# [291]	validation_0-rmse:526.86011
# [292]	validation_0-rmse:526.43278
# [293]	validation_0-rmse:525.40813
# [294]	validation_0-rmse:525.32506
# [295]	validation_0-rmse:525.27816
# [296]	validation_0-rmse:525.23122
# [297]	validation_0-rmse:525.02340
# [298]	validation_0-rmse:524.95374
# [299]	validation_0-rmse:524.86981
# [300]	validation_0-rmse:524.82222
# [301]	validation_0-rmse:524.70324
# [302]	validation_0-rmse:524.57699
# [303]	validation_0-rmse:524.53533
# [304]	validation_0-rmse:524.00224
# [305]	validation_0-rmse:523.85505
# [306]	validation_0-rmse:523.56861
# [307]	validation_0-rmse:523.38685
# [308]	validation_0-rmse:523.15320
# [309]	validation_0-rmse:523.02656
# [310]	validation_0-rmse:522.84478
# [311]	validation_0-rmse:522.74066
# [312]	validation_0-rmse:522.50123
# [313]	validation_0-rmse:522.55458
# [314]	validation_0-rmse:522.34733
# [315]	validation_0-rmse:522.31377
# [316]	validation_0-rmse:522.33713
# [317]	validation_0-rmse:522.26339
# [318]	validation_0-rmse:522.08137
# [319]	validation_0-rmse:521.80233
# [320]	validation_0-rmse:521.80210
# [321]	validation_0-rmse:521.36520
# [322]	validation_0-rmse:521.12583
# [323]	validation_0-rmse:521.11595
# [324]	validation_0-rmse:521.08424
# [325]	validation_0-rmse:521.29279
# [326]	validation_0-rmse:521.14607
# [327]	validation_0-rmse:521.03220
# [328]	validation_0-rmse:520.90572
# [329]	validation_0-rmse:521.18037
# [330]	validation_0-rmse:521.07326
# [331]	validation_0-rmse:520.97941
# [332]	validation_0-rmse:520.85119
# [333]	validation_0-rmse:520.86149
# [334]	validation_0-rmse:520.85011
# [335]	validation_0-rmse:520.69654
# [336]	validation_0-rmse:520.60849
# [337]	validation_0-rmse:520.72978
# [338]	validation_0-rmse:520.21205
# [339]	validation_0-rmse:520.18542
# [340]	validation_0-rmse:520.15064
# [341]	validation_0-rmse:520.20485
# [342]	validation_0-rmse:520.18242
# [343]	validation_0-rmse:519.80744
# [344]	validation_0-rmse:519.70362
# [345]	validation_0-rmse:519.50628
# [346]	validation_0-rmse:519.51420
# [347]	validation_0-rmse:519.35692
# [348]	validation_0-rmse:519.65017
# [349]	validation_0-rmse:519.54045
# [350]	validation_0-rmse:519.44837
# [351]	validation_0-rmse:519.42317
# [352]	validation_0-rmse:520.09993
# [353]	validation_0-rmse:520.03960
# [354]	validation_0-rmse:519.99066
# [355]	validation_0-rmse:519.88669
# [356]	validation_0-rmse:519.64632
# [357]	validation_0-rmse:519.52335
# [358]	validation_0-rmse:519.14510
# [359]	validation_0-rmse:518.99835
# [360]	validation_0-rmse:519.06492
# [361]	validation_0-rmse:519.04611
# [362]	validation_0-rmse:518.94752
# [363]	validation_0-rmse:518.78186
# [364]	validation_0-rmse:518.49360
# [365]	validation_0-rmse:518.06901
# [366]	validation_0-rmse:518.06706
# [367]	validation_0-rmse:518.05581
# [368]	validation_0-rmse:518.01658
# [369]	validation_0-rmse:518.50785
# [370]	validation_0-rmse:518.26735
# [371]	validation_0-rmse:517.92447
# [372]	validation_0-rmse:517.77724
# [373]	validation_0-rmse:517.75958
# [374]	validation_0-rmse:517.30775
# [375]	validation_0-rmse:517.18897
# [376]	validation_0-rmse:516.95955
# [377]	validation_0-rmse:516.83438
# [378]	validation_0-rmse:516.77736
# [379]	validation_0-rmse:516.78021
# [380]	validation_0-rmse:516.67054
# [381]	validation_0-rmse:516.52373
# [382]	validation_0-rmse:516.38401
# [383]	validation_0-rmse:516.25214
# [384]	validation_0-rmse:516.08538
# [385]	validation_0-rmse:516.02099
# [386]	validation_0-rmse:515.92250
# [387]	validation_0-rmse:516.10453
# [388]	validation_0-rmse:515.99794
# [389]	validation_0-rmse:515.88341
# [390]	validation_0-rmse:515.82855
# [391]	validation_0-rmse:515.91700
# [392]	validation_0-rmse:515.88045
# [393]	validation_0-rmse:515.82300
# [394]	validation_0-rmse:515.77826
# [395]	validation_0-rmse:515.76919
# [396]	validation_0-rmse:515.74595
# [397]	validation_0-rmse:515.63532
# [398]	validation_0-rmse:515.74536
# [399]	validation_0-rmse:515.63101
# [400]	validation_0-rmse:515.66491
# [401]	validation_0-rmse:515.19642
# [402]	validation_0-rmse:515.19152
# [403]	validation_0-rmse:515.22379
# [404]	validation_0-rmse:515.08017
# [405]	validation_0-rmse:515.01832
# [406]	validation_0-rmse:514.91103
# [407]	validation_0-rmse:514.78376
# [408]	validation_0-rmse:514.64399
# [409]	validation_0-rmse:514.46660
# [410]	validation_0-rmse:514.45030
# [411]	validation_0-rmse:515.40135
# [412]	validation_0-rmse:515.39461
# [413]	validation_0-rmse:515.31384
# [414]	validation_0-rmse:515.24219
# [415]	validation_0-rmse:515.07771
# [416]	validation_0-rmse:515.03316
# [417]	validation_0-rmse:514.97134
# [418]	validation_0-rmse:514.84205
# [419]	validation_0-rmse:515.01804
# [420]	validation_0-rmse:514.68056
# [421]	validation_0-rmse:514.56164
# [422]	validation_0-rmse:514.49649
# [423]	validation_0-rmse:514.50067
# [424]	validation_0-rmse:514.23869
# [425]	validation_0-rmse:514.11199
# [426]	validation_0-rmse:514.05655
# [427]	validation_0-rmse:514.08081
# [428]	validation_0-rmse:513.95309
# [429]	validation_0-rmse:513.87793
# [430]	validation_0-rmse:513.84933
# [431]	validation_0-rmse:513.79471
# [432]	validation_0-rmse:513.75546
# [433]	validation_0-rmse:513.92846
# [434]	validation_0-rmse:513.98074
# [435]	validation_0-rmse:513.95456
# [436]	validation_0-rmse:513.94457
# [437]	validation_0-rmse:514.60299
# [438]	validation_0-rmse:514.50729
# [439]	validation_0-rmse:514.43289
# [440]	validation_0-rmse:514.32035
# [441]	validation_0-rmse:514.30727
# [442]	validation_0-rmse:514.22166
# [443]	validation_0-rmse:514.16934
# [444]	validation_0-rmse:514.09892
# [445]	validation_0-rmse:514.02237
# [446]	validation_0-rmse:514.40971
# [447]	validation_0-rmse:514.37419
# [448]	validation_0-rmse:514.23836
# [449]	validation_0-rmse:514.15068
# [450]	validation_0-rmse:514.05318
# [451]	validation_0-rmse:514.65177
# [452]	validation_0-rmse:514.52975
# [453]	validation_0-rmse:514.47033
# [454]	validation_0-rmse:514.19541
# [455]	validation_0-rmse:514.17632
# [456]	validation_0-rmse:514.14348
# [457]	validation_0-rmse:513.96261
# [458]	validation_0-rmse:513.98271
# [459]	validation_0-rmse:513.85990
# [460]	validation_0-rmse:513.71472
# [461]	validation_0-rmse:513.51750
# [462]	validation_0-rmse:513.52250
# [463]	validation_0-rmse:513.40402
# [464]	validation_0-rmse:513.54586
# [465]	validation_0-rmse:514.31613
# [466]	validation_0-rmse:514.24282
# [467]	validation_0-rmse:514.08738
# [468]	validation_0-rmse:513.98726
# [469]	validation_0-rmse:513.87886
# [470]	validation_0-rmse:513.85150
# [471]	validation_0-rmse:513.76113
# [472]	validation_0-rmse:513.79296
# [473]	validation_0-rmse:514.05304
# [474]	validation_0-rmse:513.96154
# [475]	validation_0-rmse:513.98227
# [476]	validation_0-rmse:514.00361
# [477]	validation_0-rmse:513.90234
# [478]	validation_0-rmse:513.86063
# [479]	validation_0-rmse:513.90877
# [480]	validation_0-rmse:513.92382
# [481]	validation_0-rmse:514.02339
# [482]	validation_0-rmse:513.74952
# [483]	validation_0-rmse:513.80159
# [484]	validation_0-rmse:513.84920
# [485]	validation_0-rmse:513.74469
# [486]	validation_0-rmse:513.69130
# [487]	validation_0-rmse:513.75635
# [488]	validation_0-rmse:513.73553
# [489]	validation_0-rmse:513.71975
# [490]	validation_0-rmse:513.70162
# [491]	validation_0-rmse:513.65372
# [492]	validation_0-rmse:513.66591
# [493]	validation_0-rmse:513.83376
# [494]	validation_0-rmse:513.90476
# [495]	validation_0-rmse:513.86807
# [496]	validation_0-rmse:513.71448
# [497]	validation_0-rmse:513.61780
# [498]	validation_0-rmse:513.60053
# [499]	validation_0-rmse:513.64175
# [500]	validation_0-rmse:513.68281
# [501]	validation_0-rmse:513.60122
# [502]	validation_0-rmse:513.52815
# [503]	validation_0-rmse:513.42217
# [504]	validation_0-rmse:513.31747
# [505]	validation_0-rmse:513.37393
# [506]	validation_0-rmse:513.36600
# [507]	validation_0-rmse:513.23041
# [508]	validation_0-rmse:513.37169
# [509]	validation_0-rmse:513.34493
# [510]	validation_0-rmse:513.16452
# [511]	validation_0-rmse:513.12910
# [512]	validation_0-rmse:512.92685
# [513]	validation_0-rmse:512.90971
# [514]	validation_0-rmse:512.90782
# [515]	validation_0-rmse:512.93570
# [516]	validation_0-rmse:512.87753
# [517]	validation_0-rmse:512.75920
# [518]	validation_0-rmse:512.67424
# [519]	validation_0-rmse:512.57583
# [520]	validation_0-rmse:512.63348
# [521]	validation_0-rmse:512.58294
# [522]	validation_0-rmse:512.50567
# [523]	validation_0-rmse:511.80068
# [524]	validation_0-rmse:511.62653
# [525]	validation_0-rmse:511.66831
# [526]	validation_0-rmse:511.64586
# [527]	validation_0-rmse:511.62732
# [528]	validation_0-rmse:511.56022
# [529]	validation_0-rmse:511.14253
# [530]	validation_0-rmse:510.93709
# [531]	validation_0-rmse:510.82058
# [532]	validation_0-rmse:510.85748
# [533]	validation_0-rmse:510.83976
# [534]	validation_0-rmse:510.72648
# [535]	validation_0-rmse:510.66772
# [536]	validation_0-rmse:510.62961
# [537]	validation_0-rmse:510.62182
# [538]	validation_0-rmse:510.54434
# [539]	validation_0-rmse:510.48867
# [540]	validation_0-rmse:510.49321
# [541]	validation_0-rmse:510.58962
# [542]	validation_0-rmse:511.11961
# [543]	validation_0-rmse:511.07124
# [544]	validation_0-rmse:512.11837
# [545]	validation_0-rmse:512.15375
# [546]	validation_0-rmse:512.03686
# [547]	validation_0-rmse:512.04233
# [548]	validation_0-rmse:512.05784
# [549]	validation_0-rmse:511.95360
# [550]	validation_0-rmse:511.92156
# [551]	validation_0-rmse:511.75314
# [552]	validation_0-rmse:511.71632
# [553]	validation_0-rmse:511.72391
# [554]	validation_0-rmse:511.71408
# [555]	validation_0-rmse:511.70462
# [556]	validation_0-rmse:511.69995
# [557]	validation_0-rmse:511.68232
# [558]	validation_0-rmse:511.67493
# [559]	validation_0-rmse:511.43634
# [560]	validation_0-rmse:511.39423
# [561]	validation_0-rmse:511.28562
# [562]	validation_0-rmse:511.24553
# [563]	validation_0-rmse:511.15575
# [564]	validation_0-rmse:511.39628
# [565]	validation_0-rmse:511.37092
# [566]	validation_0-rmse:511.23457
# [567]	validation_0-rmse:511.16682
# [568]	validation_0-rmse:511.13614
# [569]	validation_0-rmse:511.08437
# [570]	validation_0-rmse:511.07527
# [571]	validation_0-rmse:510.99975
# [572]	validation_0-rmse:511.05267
# [573]	validation_0-rmse:511.04556
# [574]	validation_0-rmse:511.01999
# [575]	validation_0-rmse:510.89868
# [576]	validation_0-rmse:510.99628
# [577]	validation_0-rmse:510.99244
# [578]	validation_0-rmse:510.99415
# [579]	validation_0-rmse:510.98631
# [580]	validation_0-rmse:510.94206
# [581]	validation_0-rmse:510.93608
# [582]	validation_0-rmse:510.89732
# [583]	validation_0-rmse:510.84887
# [584]	validation_0-rmse:510.80798
# [585]	validation_0-rmse:510.70115
# [586]	validation_0-rmse:510.97868
# [587]	validation_0-rmse:511.03749
# [588]	validation_0-rmse:511.02529
# [589]	validation_0-rmse:510.99896
#   Fold 5 RMSE: 510.4887
# Average XGBoost RMSE: 454.8399
#
#
# --- Evaluating LightGBM ---
#   Fold 1 RMSE: 484.9154
#   Fold 2 RMSE: 555.2319
#   Fold 3 RMSE: 371.0164
#   Fold 4 RMSE: 331.0886
#   Fold 5 RMSE: 507.4982
# Average LightGBM RMSE: 449.9501
#
#
# --- Evaluating CatBoost ---
#   Fold 1 RMSE: 461.5081
#   Fold 2 RMSE: 504.9261
#   Fold 3 RMSE: 385.8901
#   Fold 4 RMSE: 355.2606
#   Fold 5 RMSE: 507.1947
# Average CatBoost RMSE: 442.9559
#
#
# --- Evaluating GradientBoosting ---
#   Fold 1 RMSE: 490.7050
#   Fold 2 RMSE: 533.4224
#   Fold 3 RMSE: 391.6118
#   Fold 4 RMSE: 358.8687
#   Fold 5 RMSE: 511.6424
# Average GradientBoosting RMSE: 457.2501
#
#
# --- Evaluating RandomForest ---
#   Fold 1 RMSE: 618.7752
#   Fold 2 RMSE: 660.0500
#   Fold 3 RMSE: 554.3155
#   Fold 4 RMSE: 514.6799
#   Fold 5 RMSE: 618.4805
# Average RandomForest RMSE: 593.2602
#
#
# --- Best Model Selected: CatBoost with average RMSE: 442.9559 ---
# Retraining CatBoost on the full training data...
# Final Training RMSE with best model (CatBoost): 260.0188
#
# --- Generating Predictions and Submission File ---
# Submission file 'submission_file.csv' created successfully.
#
# Top 5 rows of the submission file:
#           route_key  final_seatcount
# 0  2025-02-11_46_45             1652
# 1  2025-01-20_17_23              860
# 2  2025-01-08_02_14              925
# 3  2025-01-08_08_47              683
# 4  2025-01-08_09_46             1380
#
# --- Top 15 Feature Importances for CatBoost ---
#         Value                   Feature
# 11  28.407864                     route
# 12  23.700518    cumsum_seatcount_dbd_5
# 13  14.551426  cumsum_searchcount_dbd_5
# 4    4.383707               day_of_week
# 5    3.624799               day_of_year
# 2    2.593544                     month
# 3    2.447985                      year
# 1    2.202128                    destid
# 18   1.794336       srcid_region_dbd_15
# 0    1.789091                     srcid
# 6    1.702152              week_of_year
# 19   1.608635      destid_region_dbd_15
# 26   1.380736              srcid_region
# 14   1.227446   cumsum_seatcount_dbd_10
# 27   1.173322             destid_region
